# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "https://www.phius.org/certified-project-database/santaella-gardens"

html = urlopen(url).read()

onesoup = BeautifulSoup(html)

# %%
loc = onesoup.find_all(attrs={'class': 'location'})

# %%
onesoup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="og: https://ogp.me/ns#"><head>
#     <meta charset="utf-8"/>
# <link href="https://www.phius.org/certified-project-database/fairplay" rel="canonical"/>
# <meta content="website" property="og:type"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="https://www.phius.org/themes/custom/phius/assets/images/phius-og-image-1200x630.jpg" property="og:image"/>
# <link href="/core/misc/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#
#     <title>Fairplay | PHIUS</title>
#
#     <link href="https://d1azc1qln24ryf.cloudfront.net/55136/Phiusorg/style-cf.css?iix82e" rel="stylesheet"/>
#     <link href="/themes/custom/phius/assets/pwa/icons/favicon.ico" rel="icon"/>
#     <link href="/themes/custom/phius/assets/pwa/icons/favicon.svg" rel="icon" type="image/svg+xml"/>
#     <link href="/themes/custom/phius/assets/pwa/icons/apple-touch-icon.png" rel="apple-touch-icon"/>
#     <meta content="#ff0000" name="theme-color"/>
#
#     <link href="/sites/default/files/css/css_87GMcmxT1ib8ziQiU2KUAnTDFtZQV6iP-KGslA9LigM.css" media="all" rel="stylesheet"/>
# <link href="/sites/default/files/css/css_BjX8fuCECMUqbb76cr_J-0dCf22Yx_DO4AqxWYt4DYQ.css" media="all" rel="stylesheet"/>
#
#
#   </head>
#   <body>
#         <a class="skiplink" href="#maincontent">Skip to main content</a>
#
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
#     <div class="hidden" data-drupal-messages-fallback=""></div>
#
#
# <div class="page-container">
#
#
#   <header class="site-header js-site-header" data-is-alliance="false">
#
#               <section class="super-nav">
#   <div class="inner">
#               <nav aria-label="Quick Links" class="nav-links">
#         <ul>
#                       <li tabindex="-1">
#               <a data-active="false" href="/find-professional" target="_self">
#                 Find a Professional
#               </a>
#             </li>
#                       <li tabindex="-1">
#               <a data-active="false" href="/resource-library" target="_self">
#                 Resources
#               </a>
#             </li>
#                       <li tabindex="-1">
#               <a data-active="false" href="/blog" target="_self">
#                 Klingenblog
#               </a>
#             </li>
#                       <li tabindex="-1">
#               <a data-active="false" href="/browse-all-events" target="_self">
#                 Browse All Events
#               </a>
#             </li>
#                   </ul>
#       </nav>
#
#               <nav aria-label="Alliance Member Engagement Buttons" class="nav-buttons">
#         <ul>
#                                 <li class="alliance-or-get-local" tabindex="-1">
#               <a class="alliance-btn" data-active="false" href="/alliance" target="_self">
#                 Phius Alliance
#               </a>
#             </li>
#
#
#                                                             <li class="user-account-item" tabindex="-1">
#                 <a data-active="false" href="/alliance/membership" target="_blank">
#                   Join
#                 </a>
#               </li>
#                                         <li class="user-account-item" tabindex="-1">
#                 <a data-active="false" href="https://phius.fieldtech.io/" target="_blank">
#                   Member Login
#                 </a>
#               </li>
#
#                                 <li class="donate" tabindex="-1">
#               <a data-active="false" href="/donate" target="_self">
#                 Donate
#               </a>
#             </li>
#
#         </ul>
#       </nav>
#
#   </div>
# </section>
#
#
#     <div class="site-header-inner">
#                      <a aria-label="Passive House Institute US (PHIUS)" class="logo" href="/">
#           <svg height="2.136in" viewBox="0 0 422.481 153.795" width="5.868in" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#   <defs>
#     <linearGradient gradientTransform="translate(196.135 25.733) rotate(89.2)" gradientUnits="userSpaceOnUse" id="linear-gradient" x1="85.02" x2="85.02" y1="95.693" y2="128.227">
#       <stop offset="0.001" stop-color="#00a9ae"></stop>
#       <stop offset="0.113" stop-color="#04a1a6"></stop>
#       <stop offset="0.292" stop-color="#118b8e"></stop>
#       <stop offset="0.515" stop-color="#246769"></stop>
#       <stop offset="0.524" stop-color="#256567"></stop>
#       <stop offset="0.666" stop-color="#187d80"></stop>
#       <stop offset="0.882" stop-color="#079da1"></stop>
#       <stop offset="1" stop-color="#00a9ae"></stop>
#     </linearGradient>
#   </defs>
#   <g>
#     <g>
#       <path d="M226.214,81.922c0,17.1-12.3,30.876-29.4,30.876a23.805,23.805,0,0,1-19.067-8.857v29.524a1.744,1.744,0,0,1-1.845,1.846h-9.226a1.745,1.745,0,0,1-1.846-1.846V53.505a1.743,1.743,0,0,1,1.846-1.845h8a1.811,1.811,0,0,1,1.845,1.845l.492,7.012a23.821,23.821,0,0,1,19.8-10.087C213.913,50.43,226.214,64.33,226.214,81.922ZM213.789,81.8c0-11.317-7.749-19.682-18.206-19.682-10.7,0-18.206,8.857-18.206,19.682s7.5,19.191,18.206,19.191C206.04,100.989,213.789,92.747,213.789,81.8Z" style="fill: #4d4c4d"></path>
#       <path d="M287.477,75.032v35.06a1.744,1.744,0,0,1-1.845,1.845H276.4a1.744,1.744,0,0,1-1.845-1.845V76.878c0-10.334-5.29-14.762-12.424-14.762-10.457,0-15.746,10.333-15.746,12.916v35.06a1.744,1.744,0,0,1-1.846,1.845h-9.226a1.743,1.743,0,0,1-1.845-1.845V23.981a1.744,1.744,0,0,1,1.845-1.846h9.226a1.745,1.745,0,0,1,1.846,1.846V61.624c4.182-6.4,10.7-11.318,19.682-11.318C278.5,50.306,287.477,58.917,287.477,75.032Z" style="fill: #4d4c4d"></path>
#       <path d="M294.381,31.239a7.443,7.443,0,1,1,7.5,7.5A7.379,7.379,0,0,1,294.381,31.239ZM297.21,51.66h9.227a1.742,1.742,0,0,1,1.844,1.845v56.587a1.743,1.743,0,0,1-1.844,1.845H297.21a1.743,1.743,0,0,1-1.845-1.845V53.505A1.743,1.743,0,0,1,297.21,51.66Z" style="fill: #4d4c4d"></path>
#       <path d="M370.646,53.505v56.587a1.743,1.743,0,0,1-1.845,1.845h-8.734a1.811,1.811,0,0,1-1.845-1.845l-.492-7.135c-4.183,6.028-10.334,10.579-18.576,10.579-13.655,0-22.511-8.856-22.511-24.972V53.505a1.742,1.742,0,0,1,1.844-1.845h9.227a1.743,1.743,0,0,1,1.845,1.845V86.719c0,10.457,5.536,15.008,12.794,15.008,10.087,0,15.377-9.1,15.377-13.163V53.505a1.743,1.743,0,0,1,1.846-1.845H368.8A1.742,1.742,0,0,1,370.646,53.505Z" style="fill: #4d4c4d"></path>
#       <path d="M422.481,95.37c0,10.949-11.195,17.714-21.9,17.714A30.527,30.527,0,0,1,377.826,103a1.741,1.741,0,0,1,0-2.46l3.813-5.044c.738-1.107,1.476-.861,2.583,0,4.06,3.075,9.842,6.52,15.993,6.52,5.412,0,9.717-2.092,9.717-6.889,0-11.81-31-7.258-31-27.433,0-10.7,9.35-17.468,20.175-17.468a27.066,27.066,0,0,1,20.052,9.1,1.9,1.9,0,0,1-.123,2.584l-3.445,4.551c-.738.985-1.6.615-2.706-.123-4.675-3.69-8-5.535-13.04-5.535-4.059,0-8.488,2.091-8.488,6.765C391.357,79.255,422.481,73.6,422.481,95.37Z" style="fill: #4d4c4d"></path>
#     </g>
#     <g>
#       <rect height="15.541" style="fill: url(#linear-gradient)" transform="translate(-28.468 195.756) rotate(-89.2)" width="32.018" x="69.011" y="104.542"></rect>
#       <path d="M77.735,153.795C35.182,153.779.314,119.55,0,77.479A76.9,76.9,0,0,1,76.9,0,63.143,63.143,0,0,1,139.97,63.072c0,27.429-19.234,56.581-54.881,56.581-12.927,0-24.429-4.806-32.388-13.535-8.144-8.931-11.937-21.33-10.682-34.913,1.8-19.5,19.235-35.369,38.86-35.369A30.456,30.456,0,0,1,111.3,66.258,25.937,25.937,0,0,1,93.089,90.987l-.076,5.426L77.474,96.2l.251-17.99a1.619,1.619,0,0,1,1.62-1.6h5.843a10.539,10.539,0,0,0,10.569-10.66A14.9,14.9,0,0,0,80.879,51.376c-11.611,0-22.32,9.736-23.385,21.259-.86,9.311,1.453,17.268,6.69,23.012,4.979,5.459,12.4,8.466,20.905,8.466,19.549,0,39.338-14.1,39.34-41.036A47.651,47.651,0,0,0,76.481,15.542,61.356,61.356,0,0,0,15.543,77.364c.246,33.286,27.683,60.42,61.344,60.884l.14-10.037,15.539.217-.152,10.922A14.74,14.74,0,0,1,77.735,153.795Z" style="fill: #00a9ae"></path>
#     </g>
#   </g>
# </svg>
#         </a>
#
#             <nav aria-label="Main Site Navigation" class="nav js-site-header-nav">
#         <ul class="nav-items">
#
#
#
#                                     <li class="item js-site-header-nav-top-item" data-active="false" data-child-ct="2" data-children="true" data-menu-layout="long-features-with-link-list" data-menu-num-cols="2" tabindex="-1">
#                               <button class="link">
#                   Passive Building
#                 </button>
#
#                                             <div class="dropdown">
#
#
#                   <div class="menu-bottom">
#
#                     <div class="menu-group">
#
#                                             <ul class="menu js-matchheight-parent">
#
#
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis js-matchheight-target">
#
#
#                                                             <a class="title" data-active="false" href="/passive-building/what-passive-building" target="_self">
#                                 What is Passive Building?
#                               </a>
#
#                                                                                             <div class="description">
#                                   Your passive building questions, answered
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                       <ul class="main-page-list">
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/passive-building" target="_self">
#                                       Passive Building
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/what-passive-building/passive-building-principles" target="_self">
#                                       Passive Building Principles
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/what-passive-building/passive-building-faqs" target="_self">
#                                       Passive Building FAQs
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/what-passive-building/better-way-zero" target="_self">
#                                       A Better Way to Zero
#                                     </a>
#                                   </li>
#                                                               </ul>
#                                                       </li>
#
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis js-matchheight-target">
#
#
#                                                             <a class="title" data-active="false" href="/passive-building/passive-building" target="_self">
#                                 Sectors
#                               </a>
#
#                                                                                             <div class="description">
#                                   Passive isn't just for houses
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                       <ul class="main-page-list">
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/sectors/single-family" target="_self">
#                                       Single-Family
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/sectors/multifamily" target="_self">
#                                       Multifamily
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/sectors/office-buildings" target="_self">
#                                       Office Buildings
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/sectors/schools" target="_self">
#                                       Schools
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/passive-building/sectors/other-non-residential-projects" target="_self">
#                                       Other Non-Residential
#                                     </a>
#                                   </li>
#                                                               </ul>
#                                                       </li>
#                                               </ul>
#                     </div>
#                   </div>
#                 </div>
#                           </li>
#
#
#
#
#
#                                     <li class="item js-site-header-nav-top-item" data-active="false" data-child-ct="3" data-children="true" data-menu-layout="long-features-with-link-list" data-menu-num-cols="3" tabindex="-1">
#                               <button class="link">
#                   Certifications
#                 </button>
#
#                                             <div class="dropdown">
#
#
#                   <div class="menu-bottom">
#
#                     <div class="menu-group">
#
#                                             <ul class="menu js-matchheight-parent">
#
#
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis js-matchheight-target">
#
#
#                                                             <a class="title" data-active="false" href="/certifications/projects" target="_self">
#                                 Projects
#                               </a>
#
#                                                                                             <div class="description">
#                                   Project Certification is vital to the Phius mission
#                                 </div>
#
#                                                                                             <a class="btn -ghost -small" href="/certified-project-database" target="_self">
#                                   Find a Project
#                                 </a>
#                                                           </div>
#
#                                                                                       <ul class="main-page-list">
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/projects/project-certification-overview" target="_self">
#                                       Learn More About Project Certification
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/projects/submit-project" target="_self">
#                                       Submit a Project
#                                     </a>
#                                   </li>
#                                                               </ul>
#                                                       </li>
#
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis js-matchheight-target">
#
#
#                                                             <a class="title" data-active="false" href="/certifications/products" target="_self">
#                                 Products
#                               </a>
#
#                                                                                             <div class="description">
#                                   Phius Certified products are guaranteed to perform to passive standards
#                                 </div>
#
#                                                                                             <a class="btn -ghost -small" href="/product-certification-overview" target="_self">
#                                   View Products
#                                 </a>
#                                                           </div>
#
#                                                                                       <ul class="main-page-list">
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/products/phius-window-certification-program" target="_self">
#                                       Window Certification
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/products/prefabricated-panel-certification-program" target="_self">
#                                       Panel Certification
#                                     </a>
#                                   </li>
#                                                               </ul>
#                                                       </li>
#
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis js-matchheight-target">
#
#
#                                                             <a class="title" data-active="false" href="/certifications/professionals" target="_self">
#                                 Professionals
#                               </a>
#
#                                                                                             <div class="description">
#                                   Phius professionals are on the cutting edge of high-performance building
#                                 </div>
#
#                                                                                             <a class="btn -ghost -small" href="/find-professional" target="_self">
#                                   Find a Professional
#                                 </a>
#                                                           </div>
#
#                                                                                       <ul class="main-page-list">
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/professionals/phius-certified-consultant-cphc" target="_self">
#                                       Phius Certified Consultant (CPHC®)
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/professionals/phius-certified-builder-cphb" target="_self">
#                                       Phius Certified Builder (CPHB)
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/professionals/phius-certified-rater" target="_self">
#                                       Phius Certified Rater
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/certifications/professionals/phius-certified-verifier" target="_self">
#                                       Phius Certified Verifier
#                                     </a>
#                                   </li>
#                                                                   <li class="main-page-list-item">
#                                     <a data-active="false" href="/maintain-credentials" target="_self">
#                                       Maintain Credentials
#                                     </a>
#                                   </li>
#                                                               </ul>
#                                                       </li>
#                                               </ul>
#                     </div>
#                   </div>
#                 </div>
#                           </li>
#
#
#
#
#
#                                     <li class="item js-site-header-nav-top-item" data-active="false" data-child-ct="3" data-children="true" data-menu-layout="button-strip-with-feature-list" data-menu-num-cols="3" tabindex="-1">
#                               <button class="link">
#                   Standards
#                 </button>
#
#                                             <div class="dropdown">
#
#                                                         <div class="featured-links">
#
#                                                                     <div class="runin">Our Approach</div>
#
#                       <ul class="list">
#                                                   <li>
#                             <a class="link" data-active="false" href="/standards" target="_self">
#                               Phius Standards
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/passive-building/what-passive-building/better-way-zero" target="_self">
#                               Zero Carbon Standards
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/feasibility-study" target="_self">
#                               Feasibility Study
#                             </a>
#                           </li>
#                                               </ul>
#                     </div>
#
#                   <div class="menu-bottom">
#
#                     <div class="menu-group">
#
#                                             <ul class="menu">
#
#
#
#
#
#
#                           <li class="item js-link-event">
#                             <div class="emphasis">
#
#                                                                                             <span aria-label=" icon" class="icon icon-building-new-construction" role="img"></span>
#
#                                                             <a class="title js-link-event-link" data-active="false" href="/standards/new-construction" target="_self">
#                                 New Construction
#                               </a>
#
#                                                                                             <div class="description">
#                                   Phius CORE and Phius ZERO provide the path for constructing a Phius building from the ground up.
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#
#
#
#
#
#                           <li class="item js-link-event">
#                             <div class="emphasis">
#
#                                                                                             <span aria-label=" icon" class="icon icon-building-retrofit" role="img"></span>
#
#                                                             <a class="title js-link-event-link" data-active="false" href="/standards/retrofit" target="_self">
#                                 Retrofit
#                               </a>
#
#                                                                                             <div class="description">
#                                   Upgrade existing buildings to Phius standards using Phius CORE REVIVE and Phius ZERO REVIVE.
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#
#
#
#
#
#                           <li class="item js-link-event">
#                             <div class="emphasis">
#
#                                                                                             <span aria-label=" icon" class="icon icon-building-commercial" role="img"></span>
#
#                                                             <a class="title js-link-event-link" data-active="false" href="/standards/commercial" target="_self">
#                                 Commercial
#                               </a>
#
#                                                                                             <div class="description">
#                                   Phius standards aren't just for residential buildings. Phius CORE COMM and Phius ZERO COMM can be applied to any non-residential building.
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#                                               </ul>
#                     </div>
#                   </div>
#                 </div>
#                           </li>
#
#
#
#
#
#                                     <li class="item js-site-header-nav-top-item" data-active="false" data-child-ct="4" data-children="true" data-menu-layout="button-strip-with-feature-card-and-list" data-menu-num-cols="2" tabindex="-1">
#                               <button class="link">
#                   Education
#                 </button>
#
#                                             <div class="dropdown">
#
#                                                         <div class="featured-links">
#
#                                                                     <div class="runin">Categories</div>
#
#                       <ul class="list">
#                                                   <li>
#                             <a class="link" data-active="false" href="/trainings" target="_self">
#                               Trainings
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/webinars" target="_self">
#                               Webinars
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/conferences" target="_self">
#                               Conferences
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/education" target="_self">
#                               Education Overview
#                             </a>
#                           </li>
#                                                   <li>
#                             <a class="link" data-active="false" href="/browse-all-events" target="_self">
#                               Browse Events
#                             </a>
#                           </li>
#                                               </ul>
#                     </div>
#
#                   <div class="menu-bottom">
#                                                               <div class="featured-card js-link-event">
#                         <div class="inner">
#                           <div class="text">
#                                                         <div class="eyebrow">April 26 – 28</div>
#
#                                                         <div class="title">Phius Developer's Summit</div>
#
#                                                         <a class="link js-link-event-link" data-active="false" href="/browse-all-events/phius-developers-summit" target="_self">
#                               A summit for developers, real estate professionals, and passive building professionals.
#                             </a>
#                           </div>
#
#                             <picture>
#                         <source srcset="https://www.phius.org/sites/default/files/styles/450x253/public/2022-03/1391-MF-Exterior1.webp?h=c6980913&amp;itok=l0OBEqmP" type="image/webp"/>
#                               <img alt="" src="https://www.phius.org/sites/default/files/styles/450x253/public/2022-03/1391-MF-Exterior1.jpg?h=c6980913&amp;itok=l0OBEqmP"/>
#
#       </picture>
#
#                         </div>
#                       </div>
#
#                     <div class="menu-group">
#                                                                     <div class="eyebrow">Upcoming Sessions</div>
#
#                                             <ul class="menu">
#
#
#
#
#                           <li class="item">
#                             <div class="emphasis">
#
#
#                                                             <a class="title" data-active="false" href="/browse-all-events/phius-alliance-webinar-multifamily-calculator-al-mitchell" target="_self">
#                                 Phius Alliance Webinar: Multifamily Calculator with Al Mitchell
#                               </a>
#
#                                                                                             <div class="description">
#                                   April 12
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#
#
#
#                           <li class="item">
#                             <div class="emphasis">
#
#
#                                                             <a class="title" data-active="false" href="/browse-all-events/canadian-member-meeting" target="_self">
#                                 Canadian Member Meeting
#                               </a>
#
#                                                                                             <div class="description">
#                                   April 14
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#
#
#
#                           <li class="item">
#                             <div class="emphasis">
#
#
#                                                             <a class="title" data-active="false" href="/browse-all-events/phius-certified-builder-training-april-2022" target="_self">
#                                 Phius Certified Builder Training | April 2022
#                               </a>
#
#                                                                                             <div class="description">
#                                   April 19 – 30
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#
#
#
#                           <li class="item">
#                             <div class="emphasis">
#
#
#                                                             <a class="title" data-active="false" href="/browse-all-events/member-office-hours-wufi-passive" target="_self">
#                                 Member Office Hours - WUFI Passive
#                               </a>
#
#                                                                                             <div class="description">
#                                   April 19
#                                 </div>
#
#                                                                                         </div>
#
#                                                                                   </li>
#                                               </ul>
#                     </div>
#                   </div>
#                 </div>
#                           </li>
#
#
#
#
#
#
#                   </ul>
#       </nav>
#
#             <div class="utility">
#         <button aria-label="Open Search" class="search-open js-search-open"></button>
#         <button aria-label="Open Menu" class="menu-open js-menu-open"></button>
#       </div>
#     </div>
#
#         <section aria-hidden="true" class="site-header-search">
#   <div class="inner">
#
#     <div class="top">
#       <form action="/search" method="GET" role="search">
#         <span aria-hidden="true" class="icon search-icon"></span>
#         <input aria-label="Search" class="js-search-field" name="keywords" placeholder="Enter keyword" type="search"/>
#         <button class="btn -ghost submit js-search-submit" disabled="" type="submit">
#           Search
#         </button>
#       </form>
#
#       <button aria-label="Close Search" class="close js-search-close"></button>
#     </div>
#
#     <div class="bottom">
#             <article class="search-quicklinks">
#
#         <div class="eyebrow -tight">Search our databases for:</div>
#
#         <ul class="link-list">
#                   <li><a href="/find-professional">Find a Professional</a></li>
#                   <li><a href="/certified-project-database">Certified Project Database</a></li>
#                   <li><a href="/resource-library">Resource Library</a></li>
#                   <li><a href="/browse-all-events">Browse All Events</a></li>
#                 </ul>
#
#       </article>
#     </div>
#   </div>
# </section>
#
#                     <section aria-hidden="true" class="hamburger-menu" data-has-top-account-controls="" data-level="1">
#
#     <button aria-label="Close" class="close js-menu-close"></button>
#
#     <button class="back js-menu-back">
#     <span>Back</span>
#   </button>
#
#   <div class="inner">
#
#         <nav aria-label="Side Navigation" class="nav">
#
#             <ul class="menu">
#
#
#           <li data-menu-layout="long-features-with-link-list">
#                                       <button class="link js-menu-next" data-active="false">
#                 Passive Building
#               </button>
#
#                                                     <button aria-label="View Dropdown" class="next js-menu-next"></button>
#
#                             <div aria-hidden="true" class="panel">
#                                 <div class="department-title">
#                   Passive Building
#                 </div>
#
#
#                 <div class="menu-inner">
#
#                                     <ul>
#
#
#
#
#
#                       <li class="item">
#                         <div class="emphasis js-matchheight-target">
#
#                                                     <a class="title" data-active="false" href="/passive-building/what-passive-building" target="_self">
#                             What is Passive Building?
#                           </a>
#
#
#                                                                                 <div class="description">
#                               Your passive building questions, answered
#                             </div>
#
#                                                                             </div>
#
#                                                                           <ul class="main-page-list js-menu-to-toggle">
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/passive-building" target="_self">
#                                   Passive Building
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/what-passive-building/passive-building-principles" target="_self">
#                                   Passive Building Principles
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/what-passive-building/passive-building-faqs" target="_self">
#                                   Passive Building FAQs
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/what-passive-building/better-way-zero" target="_self">
#                                   A Better Way to Zero
#                                 </a>
#                               </li>
#                                                       </ul>
#                                               </li>
#
#
#
#
#
#                       <li class="item">
#                         <div class="emphasis js-matchheight-target">
#
#                                                     <a class="title" data-active="false" href="/passive-building/passive-building" target="_self">
#                             Sectors
#                           </a>
#
#
#                                                                                 <div class="description">
#                               Passive isn't just for houses
#                             </div>
#
#                                                                             </div>
#
#                                                                           <ul class="main-page-list js-menu-to-toggle">
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/sectors/single-family" target="_self">
#                                   Single-Family
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/sectors/multifamily" target="_self">
#                                   Multifamily
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/sectors/office-buildings" target="_self">
#                                   Office Buildings
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/sectors/schools" target="_self">
#                                   Schools
#                                 </a>
#                               </li>
#                                                           <li class="main-page-list-item">
#                                 <a data-active="false" href="/passive-building/sectors/other-non-residential-projects" target="_self">
#                                   Other Non-Residential
#                                 </a>
#                               </li>
#                                                       </ul>
#                                               </li>
#                                       </ul>
#                 </div>
#
#
#               </div>
#                       </li>
#
#
#           <li data-menu-layout="long-features-with-link-list">
#                                       <button class="link js-menu-next" data-active="false">
#                 Certifications
#               </button>
#
#                                                     <button aria-label="View Dropdown" class="next js-menu-next"></button>
#
#                             <div aria-hidden="true" class="panel">
#                                 <div class="department-title">
#                   Certifications
#                 </div>
#
#
#                 <div class="menu-inner">
#
#                                     <ul>
#
#
#
#
#
#                       <li class="item">
#                         <div class="emphasis js-matchheight-target">
#
#                                                     <a class="title" data-active="false" href="/certifications/projects" target="_self">
#                             Projects
#                           </a>
#
#
#                                                                                 <div class="description">
# ...
#       <path d="M325.431,42.875a.731.731,0,0,1,1.187,0l.863.755a.782.782,0,0,1,.054,1.132,13.317,13.317,0,0,1-23.464-8.792c0-7.767,5.609-13.862,13.215-13.862A13.044,13.044,0,0,1,327.373,26.8a.782.782,0,0,1-.054,1.133l-.863.7a.764.764,0,0,1-1.187.055c-1.564-1.457-3.4-3.668-7.983-3.668-5.933,0-10.086,4.693-10.086,10.949,0,5.88,4.153,10.573,10.086,10.573A9.932,9.932,0,0,0,325.431,42.875Z" style="fill: #767576"></path>
#       <path d="M354.559,34.622c0,1.726-.216,2.535-1.511,2.535H332.5a10.093,10.093,0,0,0,10.463,9.224,10.814,10.814,0,0,0,7.606-2.7c.378-.324.7-.54,1.133-.162l.7.647c.432.432.485.809.054,1.241a13.412,13.412,0,0,1-9.871,4.045c-7.767,0-13.269-6.095-13.269-13.7s5.286-13.647,12.892-13.647A12.241,12.241,0,0,1,354.559,34.622ZM332.5,34.46h19.2a9.462,9.462,0,0,0-9.547-9.386C336.705,25.074,333.037,29.174,332.5,34.46Z" style="fill: #767576"></path>
#     </g>
#     <g>
#       <path d="M99.182,35.918c0,7.5-5.393,13.538-12.891,13.538a10.437,10.437,0,0,1-8.359-3.884V58.517a.765.765,0,0,1-.809.809H73.077a.765.765,0,0,1-.809-.809V23.459a.764.764,0,0,1,.809-.809h3.506a.794.794,0,0,1,.809.809l.216,3.074a10.445,10.445,0,0,1,8.683-4.423C93.789,22.11,99.182,28.205,99.182,35.918Zm-5.447-.054c0-4.962-3.4-8.63-7.983-8.63-4.692,0-7.982,3.884-7.982,8.63s3.29,8.414,7.982,8.414C90.337,44.278,93.735,40.664,93.735,35.864Z" style="fill: #4d4c4d"></path>
#       <path d="M126.042,32.9V48.269a.764.764,0,0,1-.809.809h-4.045a.764.764,0,0,1-.809-.809V33.706c0-4.53-2.319-6.472-5.447-6.472-4.585,0-6.9,4.531-6.9,5.663V48.269a.764.764,0,0,1-.809.809h-4.045a.764.764,0,0,1-.81-.809V10.514a.765.765,0,0,1,.81-.809h4.045a.765.765,0,0,1,.809.809v16.5a10.136,10.136,0,0,1,8.63-4.962C122.105,22.056,126.042,25.832,126.042,32.9Z" style="fill: #4d4c4d"></path>
#       <path d="M129.069,13.7a3.263,3.263,0,1,1,3.29,3.289A3.237,3.237,0,0,1,129.069,13.7Zm1.241,8.953h4.045a.764.764,0,0,1,.809.809v24.81a.764.764,0,0,1-.809.809H130.31a.764.764,0,0,1-.809-.809V23.459A.764.764,0,0,1,130.31,22.65Z" style="fill: #4d4c4d"></path>
#       <path d="M162.507,23.459v24.81a.764.764,0,0,1-.809.809h-3.829a.794.794,0,0,1-.809-.809l-.216-3.128a9.807,9.807,0,0,1-8.144,4.638c-5.987,0-9.87-3.883-9.87-10.949V23.459a.764.764,0,0,1,.809-.809h4.045a.764.764,0,0,1,.809.809V38.021c0,4.585,2.427,6.58,5.609,6.58,4.423,0,6.742-3.991,6.742-5.771V23.459a.764.764,0,0,1,.809-.809H161.7A.764.764,0,0,1,162.507,23.459Z" style="fill: #4d4c4d"></path>
#       <path d="M185.234,41.814c0,4.8-4.909,7.767-9.6,7.767a13.383,13.383,0,0,1-9.978-4.423.763.763,0,0,1,0-1.078l1.672-2.212c.323-.485.647-.377,1.133,0,1.78,1.349,4.315,2.859,7.011,2.859,2.373,0,4.261-.917,4.261-3.021,0-5.177-13.592-3.182-13.592-12.027,0-4.693,4.1-7.659,8.846-7.659a11.863,11.863,0,0,1,8.791,3.991.835.835,0,0,1-.053,1.133l-1.511,2c-.323.431-.7.269-1.186-.054-2.05-1.618-3.506-2.427-5.718-2.427-1.779,0-3.721.916-3.721,2.966C171.588,34.749,185.234,32.268,185.234,41.814Z" style="fill: #4d4c4d"></path>
#     </g>
#     <g>
#       <rect height="6.814" style="fill: url(#linear-gradient)" transform="translate(-12.482 85.828) rotate(-89.2)" width="14.038" x="30.257" y="45.836"></rect>
#       <path d="M34.121,67.43C13.488,67.445-3.036,49.114.472,28.063A33.708,33.708,0,0,1,33.715,0,27.685,27.685,0,0,1,61.369,27.654c0,12.026-8.433,24.807-24.062,24.807a18.874,18.874,0,0,1-14.2-5.934,19.659,19.659,0,0,1-4.683-15.308A17.445,17.445,0,0,1,35.461,15.712,13.353,13.353,0,0,1,48.8,29.05a11.373,11.373,0,0,1-7.985,10.843l-.033,2.379-6.813-.095.106-7.6a1,1,0,0,1,1.005-.992H37.43a4.533,4.533,0,0,0,4.553-4.375,6.531,6.531,0,0,0-6.522-6.687,10.628,10.628,0,0,0-10.253,9.32c-.377,4.083.637,7.571,2.933,10.09a12.157,12.157,0,0,0,9.166,3.711c8.571,0,17.248-6.18,17.248-17.992A21.131,21.131,0,0,0,32.817,6.828a26.9,26.9,0,0,0-26,27.092,27.16,27.16,0,0,0,26.9,26.694l.062-4.4,6.813.095L40.518,61.1A6.417,6.417,0,0,1,34.121,67.43Z" style="fill: #00a9ae"></path>
#     </g>
#   </g>
# </svg>
#         </a>
#       </div>
#
#       <div class="site-footer-top-right">
#         <div aria-hidden="true" class="accent-lines"></div>
#
#
# <!-- components/zoho-email-form/zoho-email-form.twig -->
# <article class="zoho-email-form js-zoho-form-embed" data-parent-classname="js-site-footer">
#
#
#       <!--Zoho Campaigns Web-Optin Form Starts Here-->
# <script onload="setupSF('sf3zaecffde96a5a4adea3cb45604173933ba7ac971d4289811c6b6e87f92d517aa7','ZCFORMVIEW',false,'acc',false,'2')" src="https://qiuw.maillist-manage.com/js/optin.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	function runOnFormSubmit_sf3zaecffde96a5a4adea3cb45604173933ba7ac971d4289811c6b6e87f92d517aa7(th){
# 		/*Before submit, if you want to trigger your event, "include your code here"*/
# 	};
# </script>
#
# <meta content="width=device-width,initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <div data-type="signupform" id="sf3zaecffde96a5a4adea3cb45604173933ba7ac971d4289811c6b6e87f92d517aa7">
# 	<div id="customForm">
# 		<input id="recapTheme" type="hidden" value="2"/>
# 		<input id="isRecapIntegDone" type="hidden" value="false"/>
# 		<input id="recapMode" type="hidden" value="795484000000303053"/>
# 		<input id="signupFormType" type="hidden" value="LargeForm_Vertical"/>
# 		<div class="SIGNUP_PAGE large_form_10_css" id="SIGNUP_PAGE" name="SIGNUP_PAGE">
# 			<div>
# 				<div changeid="" changename="" name="">
# 					<div id="imgBlock" logo="true" name="LOGO_DIV"></div>
# 				</div>
# 				<br/>
# 				<div changeid="SIGNUPFORM" changename="SIGNUPFORM" id="signupMainDiv" name="SIGNUPFORM">
# 					<div>
# 						<div style="position:relative;">
# 							<div id="Zc_SignupSuccess" style="display:none;position:absolute;margin-left:4%;width:90%;background-color: white; padding: 3px; border: 3px solid rgb(194, 225, 154);  margin-top: 10px;margin-bottom:10px;word-break:break-all ">
# 								<table border="0" cellpadding="0" cellspacing="0" width="100%">
# 									<tbody>
# 										<tr>
# 											<td width="10%">
# 												<img align="absmiddle" class="successicon" src="https://qiuw.maillist-manage.com/images/challangeiconenable.jpg"/>
# 											</td>
# 											<td>
# 												<span id="signupSuccessMsg" style="color: rgb(73, 140, 132); font-family: sans-serif; font-size: 14px;word-break:break-word">  Thank you for Signing Up</span>
# 											</td>
# 										</tr>
# 									</tbody>
# 								</table>
# 							</div>
# 						</div>
# 						<form action="https://qiuw.maillist-manage.com/weboptin.zc" id="zcampaignOptinForm" method="POST" target="_zcSignup">
# 							<div id="SIGNUP_BODY_ALL" name="SIGNUP_BODY_ALL">
# 								<!-- <h1 id="SIGNUP_HEADING" name="SIGNUP_HEADING" changeid="SIGNUP_MSG" changetype="SIGNUP_HEADER"></h1> -->
# 								<div id="SIGNUP_BODY" name="SIGNUP_BODY">
# 									<div>
# 										<div changeid="SIGNUP_MSG" changetype="SIGNUP_DESCRIPTION" class="" id="SIGNUP_DESCRIPTION"></div>
# 										<div id="errorMsgDiv">  Please correct the marked field(s) below.</div>
# 										<div>
# 											<div class="zcsffieldsdiv" name="fieldsdivSf">
# 												<div class="zcsffield" fieldid="795484000000000023">
# 													<div>
# 														<div name="SIGNUP_FORM_LABEL">First Name </div>
# 														<div><!-- check to mark emailid field as type email, and other mandatory fields as type required -->
#                               <label class="sr-text" for="zoho-input--FIRSTNAME">First Name</label>
# 															<input changeitem="SIGNUP_FORM_FIELD" id="zoho-input--FIRSTNAME" maxlength="100" name="FIRSTNAME" type="text" value=""/>
# 															<span id="dt_FIRSTNAME" style="display:none">1,false,1,First Name,2</span>
# 														</div>
# 													</div>
#
#
#
#
# 											<div></div>
#
#
#
# 												</div>
# 												<div class="zcsffield" fieldid="795484000000000025">
# 													<div>
# 														<div name="SIGNUP_FORM_LABEL">Last Name </div>
# 														<div><!-- check to mark emailid field as type email, and other mandatory fields as type required -->
#                               <label class="sr-text" for="zoho-input--LASTNAME">Last Name</label>
# 															<input changeitem="SIGNUP_FORM_FIELD" id="zoho-input--LASTNAME" maxlength="100" name="LASTNAME" type="text" value=""/>
# 															<span id="dt_LASTNAME" style="display:none">1,false,1,Last Name,2</span>
# 														</div>
# 													</div><div></div></div>
# 												<div class="zcsffield" fieldid="795484000000000021">
# 													<div>
# 														<div name="SIGNUP_FORM_LABEL">Email
# 															<span name="SIGNUP_REQUIRED">*</span>
# 														</div>
# 														<div><!-- check to mark emailid field as type email, and other mandatory fields as type required -->
#                               <label class="sr-text" for="zoho-input--CONTACT_EMAIL">Contact Email</label>
# 															<input changeitem="SIGNUP_FORM_FIELD" id="zoho-input--CONTACT_EMAIL" maxlength="100" name="CONTACT_EMAIL" required="true" type="email" value=""/>
# 															<span id="dt_CONTACT_EMAIL" style="display:none">1,true,6,Contact Email,2</span>
# 														</div>
# 													</div><div></div></div>
# 											</div><!-- Captcha for Signup -->
# 											<div class="recaptcha" id="captchaOld" name="captchaContainer">
# 												<!-- <div>
# 													<div id="captchaParent">
# 														<img src="//campaigns.zoho.com/images/refresh_icon.png" onclick="loadCaptcha('https://campaigns.zoho.com/campaigns/CaptchaVerify.zc?mode=generate',this,'#sf3zaecffde96a5a4adea3cb45604173933ba7ac971d4289811c6b6e87f92d517aa7');" id="relCaptcha">
# 														<div id="captchaDiv" captcha="true" name=""></div>
# 														<input placeholder="Captcha" id="captchaText" name="captchaText" changeitem="SIGNUP_FORM_FIELD" maxlength="100" type="text">
# 														<span name="SIGNUP_REQUIRED" id="capRequired">*</span>
# 													</div>
# 												</div> -->
#                         <div>
#
#                         </div></div>
# 											<input id="secretid" type="hidden" value="6LdNeDUUAAAAAG5l7cJfv1AA5OKLslkrOa_xXxLs"/><!-- Captcha for Signup End--><!-- Other Lists Subscription Start--><!-- Other Lists Subscription End--><div></div>
# 											<div changetype="REQUIRED_FIELD_TEXT" id="REQUIRED_FIELD_TEXT" name="SIGNUP_REQUIRED">*Required Fields</div>
# 											<div>
# 												<input action="Save" changetype="SIGNUP_SUBMIT_BUTTON_TEXT" id="zcWebOptin" name="SIGNUP_SUBMIT_BUTTON" type="submit" value="Join Now"/>
# 											</div><!-- Do not edit the below Zoho Campaigns hidden tags -->
# 											<input id="fieldBorder" type="hidden" value=""/>
# 											<input id="zc_trackCode" name="zc_trackCode" onload="" type="hidden" value="ZCFORMVIEW"/>
# 											<input id="viewFrom" name="viewFrom" type="hidden" value="URL_ACTION"/>
# 											<input id="submitType" name="submitType" type="hidden" value="optinCustomView"/>
# 											<input id="lD" name="lD" type="hidden" value="1b0a207bbc856d94"/>
# 											<input id="emailReportId" name="emailReportId" type="hidden" value=""/>
# 											<input id="cmpZuid" name="zx" type="hidden" value="12bee2b4d"/>
# 											<input name="zcvers" type="hidden" value="3.0"/>
# 											<input id="allCheckedListIds" name="oldListIds" type="hidden" value=""/>
# 											<input id="mode" name="mode" type="hidden" value="OptinCreateView"/>
# 											<input id="zcld" name="zcld" type="hidden" value="1b0a207bbc856d94"/>
# 											<input id="zctd" name="zctd" type="hidden" value=""/>
# 											<input id="document_domain" type="hidden" value=""/>
# 											<input id="zc_Url" type="hidden" value="qiuw.maillist-manage.com"/>
# 											<input id="new_optin_response_in" type="hidden" value="0"/>
# 											<input id="duplicate_optin_response_in" type="hidden" value="0"/>
# 											<input id="zc_formIx" name="zc_formIx" type="hidden" value="3zaecffde96a5a4adea3cb45604173933ba7ac971d4289811c6b6e87f92d517aa7"/><!-- End of the campaigns hidden tags --></div>
# 									</div>
# 									<input id="isCaptchaNeeded" type="hidden" value="false"/>
# 									<input id="superAdminCap" type="hidden" value="0"/>
# 									<img alt="spacer" id="refImage" onload="referenceSetter(this)" src="https://qiuw.maillist-manage.com/images/spacer.gif"/>
# 								</div>
# 							</div>
# 						</form>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# <div id="zcOptinOverLay" oncontextmenu="return false" style="display:none;text-align: center; background-color: rgb(0, 0, 0); opacity: 0.5; z-index: 100; position: fixed; width: 100%; top: 0px; left: 0px; height: 988px;"></div>
# <div id="zcOptinSuccessPopup" style="display:none;z-index: 9999;width: 800px; height: 40%;top: 84px;position: fixed; left: 26%;background-color: #FFFFFF;border-color: #E6E6E6; border-style: solid; border-width: 1px;  box-shadow: 0 1px 10px #424242;padding: 35px;">
# 	<span id="closeSuccess" style="position: absolute;top: -16px;right:-14px;z-index:99999;cursor: pointer;">
# 		<img src="https://qiuw.maillist-manage.com/images/videoclose.png"/>
# 	</span>
# 	<div id="zcOptinSuccessPanel"></div>
# </div>
#
# <!--Zoho Campaigns Web-Optin Form Ends Here--></article>
#       </div>
#     </div>
#
#         <div class="site-footer-bottom">
#             <nav aria-label="Footer Navigation" class="site-footer-nav">
#         <ul>
#                       <li>
#               <a data-active="false" href="/about-us" target="_self">
#                 About Us
#               </a>
#             </li>
#                       <li>
#               <a data-active="false" href="/careers" target="_self">
#                 Careers
#               </a>
#             </li>
#                       <li>
#               <a data-active="false" href="https://forms.zohopublic.com/phius/form/ContactPhius/formperma/_u3NnJ8_l4Bcia3a4bHvPvSJQU7OKKtq-LLaVhyKeuM" target="_self">
#                 Contact Us
#               </a>
#             </li>
#                       <li>
#               <a data-active="false" href="https://phius.ecwid.com/" target="_self">
#                 Store
#               </a>
#             </li>
#                   </ul>
#       </nav>
#
#                     <nav aria-label="Social Media Links" class="site-footer-social">
#           <ul>
#                           <li>
#                 <a class="icon-facebook" href="https://www.facebook.com/PHIUS1" rel="noopener" target="_blank">
#                   <span class="sr-text">Facebook</span>
#                 </a>
#               </li>
#                           <li>
#                 <a class="icon-youtube" href="https://www.youtube.com/channel/UC37iRgzDQK-OgyoLTOn7GoA" rel="noopener" target="_blank">
#                   <span class="sr-text">YouTube</span>
#                 </a>
#               </li>
#                           <li>
#                 <a class="icon-linkedin" href="https://www.linkedin.com/company/passive-house-institute-us-phius-/mycompany/verification/?viewAsMember=true" rel="noopener" target="_blank">
#                   <span class="sr-text">LinkedIn</span>
#                 </a>
#               </li>
#                           <li>
#                 <a class="icon-twitter" href="https://twitter.com/PHIUS1" rel="noopener" target="_blank">
#                   <span class="sr-text">Twitter</span>
#                 </a>
#               </li>
#                       </ul>
#         </nav>
#
#       <div class="site-footer-bottom-right">
#                           <nav aria-label="Footer Legal Navigation" class="site-footer-legal-nav">
#             <ul>
#                               <li>
#                   <a data-active="false" href="/privacy">
#                     Privacy
#                   </a>
#                 </li>
#                           </ul>
#           </nav>
#
#                 <div class="site-footer-copyright">
#           <p>©
#             2022 Phius All Rights Reserved.</p>
#         </div>
#       </div>
#     </div>
#   </footer>
#
#
#
#     <div class="js-blocker"></div>
# </div>
#
#   </div>
#
#
#
#     <script src="/sites/default/files/js/js_wv0EPifVILVY2XZuO-Qqm4NzVKQzNylL9SZgR7UnhF8.js"></script>
#
#
#
# </body></html>

# %%
if len(loc) != 1:
    raise Exception(f"Location not unique: {loc}")

# %%
loc[0].get_text().strip()
# Out:
# 'Fairplay, Colorado'

# %%
def extract_structured_data(soup):
    '''Extract all "structured-data" fields from PHIUS project page
    
    On the project page, most of the data on project is saved like this:
    
      <ul class="structured-data">
        <li>
          <div class="label">Annual Heating Demand</div>
          <div class="value">2.11</div>
        </li>
      [...]
    
    Some of the data comes in formats that can be make more useful
    (e.g. the date could be parsed into ISO or the area converted to a number)
    but that is outside of the scope of this funtion. 
    
    
    Parameters
    ----------
    soup : 
        BeautifulSoup4 parsed html page
    
    Returns
    -------
    extracted_data : dict
        Data will all structured fields from the website
    '''
    extracted_data = {}
    for d in onesoup.find_all(attrs={'class': 'structured-data'}):
        for li in d.find_all('li'):
            key = li.find(attrs={'class': 'label'}).text
            value = li.find(attrs={'class': 'value'}).text
            extracted_data[key] = value
    return extracted_data

# %%
extracted_data
# Out:
# {'Building Function': 'Multifamily',
#  'Project Type': 'New Construction',
#  'ASHRAE Climate Zone': '4A - Mixed - Humid',
#  'Construction Completion': '2019',
#  'Status': 'Final Certified',
#  'INT. Conditioned Floor Area': '214543 sq. ft.',
#  'Phius Certified Verifier': 'Avery Gray',
#  'Phius CPHC (Lead)': 'Carmel Pratt',
#  'Project Submitter': 'Jordana Viuker',
#  'Construction Company': '1675 JV Associates LLC',
#  'Construction Type': 'Masonry',
#  'Number of Units': '249',
#  'Number of Stories': '11',
#  'Program Version': 'PHIUS+ 2015',
#  'Design Certification': 'March 29, 2019',
#  'Final Certification': 'March 25, 2022',
#  'Region': 'Northeast',
#  'Annual Heating Demand': '2.11',
#  'Annual Cooling Demand': '5.18',
#  'Peak Heating Load': '3.36',
#  'Peak Cooling Load': '2.69',
#  'Site Energy Use Index (EUI)': '24.8',
#  'Site Energy Use Index (w/Renewables)': '21.82',
#  'Compliance Software': 'WUFI Passive',
#  'Source Energy (Residential)': '6327',
#  'Source Energy (Residential w/Renewables)': '5360',
#  'Air Tightness (per enclosure area)': '0.046',
#  'Average Compartmentalization': '0.19',
#  'Facade Type': 'Masonry Veneer',
#  'Wall 1 Type': 'Other',
#  'Wall 1 R-Value': '21',
#  'Wall 1 Insulation Type': 'Mineral Wool (Board)',
#  'Wall 2 Type': 'Exterior Continuous Insulation Only',
#  'Wall 2 R-Value': '24',
#  'Wall 2 Insulation Type': 'XPS',
#  'Roof 1 Type': 'Unvented Roof',
#  'Roof 1 R-Value': '50',
#  'Roof 1 Insulation Type': 'PolyIso',
#  'Floor Type 1': 'Basement Slab',
#  'Floor 1 R-Value': '21',
#  'Floor 1 Insulation Type': 'XPS',
#  'Window Manufacturer 1': 'REHAU',
#  'Whole Window U-Value 1': '0.3',
#  'Window Glazing SHGC 1': '0.3',
#  'Window Manufacturer 2': 'REHAU',
#  'Whole Window U-Value 2': '0.3',
#  'Window Glazing SHGC 2': '0.27',
#  'Window Manufacturer 3': 'YKK',
#  'Window Product Name 3': 'YES 60 TU',
#  'Whole Window U-Value 3': '0.47',
#  'Window Glazing SHGC 3': '0.37',
#  'Ventilation System Manufacturer': 'Swegon',
#  'Ventilation System Product Name': 'Gold RX 07, 11, 14',
#  'Ventilation System Layout': 'Semi-Centralized',
#  'Ventilation System Type': 'ERV',
#  'Sensible Recovery Efficiency': '82.4',
#  'Latent Recovery Efficiency': '0.74',
#  'Measured Ventilation Fan Efficiency': '1.5',
#  'Heating System Manufacturer': 'Mitsubishi',
#  'Heating System Type': 'Variable Refrigerant Flow (VRF)',
#  'Cooling System Manufacturer': 'Mitsubishi',
#  'Cooling System Type': 'Variable Refrigerant Flow (VRF)',
#  'Hot Water System Manufacturer': 'Intellihot',
#  'Hot Water System Layout': 'Centralized',
#  'Hot Water System Type': 'Natural Gas Water Heater',
#  'Range Hood Type': 'Recirculation',
#  'Dryer Type': 'Vented',
#  'Renewable Energy Type(s)': 'On-Site PV',
#  'Renewable Energy Annual Production': '192321',
#  'Renewable Energy System Size': '162.7'}

# %%
url = "https://www.phius.org/certified-project-database?_page=1&keywords=&_limit=10000"

html = urlopen(url).read()

allsoup = BeautifulSoup(html)

# %%
def extract_project_data(soup):
    '''Extract data from a single project in the overview page
    
    On the project page, most of the data on project is saved like this:
    ```
    <article class="teaser js-link-event" data-has-image="false" data-result-type="project">
    [...]
    <span class="status final-certified">Final Certified</span></div>
    [...]
    <a class="js-link-event-link" href="/certified-project-database/tenney-residence">Tenney Residence</a>
    [...]
    <span class="building-function">Single-Family</span>
    <span class="project-type">New Construction</span></span>
    <span class="climate-zone">5B - Cool - Dry</span><div class="stats">
    <span class="sq-ft">3450 sq. ft.</span>
    [...]
    ```
    
    Most of the fields in the input data are just copied verbatim into a dict, but
    some field are processed, extracting the URL to the project detail page, and 
    converting completion date and floor area to numbers.
    
    Returns
    -------
    extracted_data : dict
    '''
    extracted_data = {}
    atag = soup.find('a')
    extracted_data['link'] = 'https://www.phius.org' + atag.get('href')
    extracted_data['title'] = atag.get_text()
    # k matches the keys that I find in "strucutred-data" on the detail pages of each project
    # v is what class is called in this page
    for v, k in [('Status', 'status'), 
                 ('Building Function', 'building-function'), 
                 ('Project Type', 'project-type'), 
                 ('ASHRAE Climate Zone', 'climate-zone'), 
                 ('INT. Conditioned Floor Area', 'sq-ft'), 
                ]:
        tag = soup.find(attrs={'class': k})
        if tag:
            extracted_data[v] = tag.get_text()
    
    completion = soup.find(attrs={'class': 'completion-date'})
    # Text is something like "Completed 2019" be we want to get only the date
    if completion:
        extracted_data['Construction Completion'] = int(completion.get_text().split(' ')[1])
    if 'INT. Conditioned Floor Area' in extracted_data:
        extracted_data['Floor area'] = float(extracted_data['INT. Conditioned Floor Area'].replace('sq. ft.', ''))
    return extracted_data

# %%
extract_project_data(projectlist[123])
# Out:
# {'link': 'https://www.phius.org/certified-project-database/modern-ocean-view-pei',
#  'title': 'Modern Ocean View PEI',
#  'Status': 'Final Certified',
#  'Building Function': 'Single-Family',
#  'Project Type': 'New Construction',
#  'ASHRAE Climate Zone': '6A - Cool - Humid',
#  'INT. Conditioned Floor Area': '3470 sq. ft.',
#  'Floor area': 3470.0}

# %%
projectlist = allsoup.find_all('article', attrs={'data-result-type': "project"})

# %%
assert len(projectlist) > 600

# %%
all_projects = {}
for p in projectlist:
    out = extract_project_data(p)
    title = out.pop('title')
    all_projects[title] = out

# %%
v
# Out:
# {'link': 'https://www.phius.org/certified-project-database/santaella-gardens',
#  'Status': 'Final Certified',
#  'Building Function': 'Multifamily',
#  'Project Type': 'New Construction',
#  'ASHRAE Climate Zone': '4A - Mixed - Humid',
#  'INT. Conditioned Floor Area': '214543 sq. ft.',
#  'Construction Completion': 2019,
#  'Floor area': 214543.0}

# %%
for p, v in all_projects.items():
    html = urlopen(v['link']).read()
    onesoup = BeautifulSoup(html)
    v.update(extract_structured_data(onesoup))

# %%
all_projects
# Out:
# {'Santaella Gardens': {'link': 'https://www.phius.org/certified-project-database/santaella-gardens',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '214543 sq. ft.',
#   'Construction Completion': '2019',
#   'Floor area': 214543.0,
#   'Phius Certified Verifier': 'Avery Gray',
#   'Phius CPHC (Lead)': 'Carmel Pratt',
#   'Project Submitter': 'Jordana Viuker',
#   'Construction Company': '1675 JV Associates LLC',
#   'Construction Type': 'Masonry',
#   'Number of Units': '249',
#   'Number of Stories': '11',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'March 29, 2019',
#   'Final Certification': 'March 25, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '2.11',
#   'Annual Cooling Demand': '5.18',
#   'Peak Heating Load': '3.36',
#   'Peak Cooling Load': '2.69',
#   'Site Energy Use Index (EUI)': '24.8',
#   'Site Energy Use Index (w/Renewables)': '21.82',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6327',
#   'Source Energy (Residential w/Renewables)': '5360',
#   'Air Tightness (per enclosure area)': '0.046',
#   'Average Compartmentalization': '0.19',
#   'Facade Type': 'Masonry Veneer',
#   'Wall 1 Type': 'Other',
#   'Wall 1 R-Value': '21',
#   'Wall 1 Insulation Type': 'Mineral Wool (Board)',
#   'Wall 2 Type': 'Exterior Continuous Insulation Only',
#   'Wall 2 R-Value': '24',
#   'Wall 2 Insulation Type': 'XPS',
#   'Roof 1 Type': 'Unvented Roof',
#   'Roof 1 R-Value': '50',
#   'Roof 1 Insulation Type': 'PolyIso',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '21',
#   'Floor 1 Insulation Type': 'XPS',
#   'Window Manufacturer 1': 'REHAU',
#   'Whole Window U-Value 1': '0.3',
#   'Window Glazing SHGC 1': '0.3',
#   'Window Manufacturer 2': 'REHAU',
#   'Whole Window U-Value 2': '0.3',
#   'Window Glazing SHGC 2': '0.27',
#   'Window Manufacturer 3': 'YKK',
#   'Window Product Name 3': 'YES 60 TU',
#   'Whole Window U-Value 3': '0.47',
#   'Window Glazing SHGC 3': '0.37',
#   'Ventilation System Manufacturer': 'Swegon',
#   'Ventilation System Product Name': 'Gold RX 07, 11, 14',
#   'Ventilation System Layout': 'Semi-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '82.4',
#   'Latent Recovery Efficiency': '0.74',
#   'Measured Ventilation Fan Efficiency': '1.5',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Variable Refrigerant Flow (VRF)',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Variable Refrigerant Flow (VRF)',
#   'Hot Water System Manufacturer': 'Intellihot',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Natural Gas Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '192321',
#   'Renewable Energy System Size': '162.7'},
#  'Oak Tree Village - Building A': {'link': 'https://www.phius.org/certified-project-database/oak-tree-village-building',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45195 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 45195.0,
#   'Phius Certified Verifier': 'Nicole Burger',
#   'Project Submitter': 'Kai Fast',
#   'Construction Company': 'Dakota Partners',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '36',
#   'Number of Stories': '4',
#   'Program Version': 'PHIUS+ 2018 CORE',
#   'Design Certification': 'July 6, 2021',
#   'Final Certification': 'March 22, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '2.85',
#   'Annual Cooling Demand': '3.25',
#   'Peak Heating Load': '2.55',
#   'Peak Cooling Load': '1.87',
#   'Site Energy Use Index (EUI)': '18.08',
#   'Site Energy Use Index (w/Renewables)': '16.95',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5761',
#   'Source Energy (Residential w/Renewables)': '5336',
#   'Air Tightness (per enclosure area)': '0.0366',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '32',
#   'Wall 1 Insulation Type': 'PolyIso, Cellulose',
#   'Wall 2 Type': 'Exterior Continuous Insulation Only',
#   'Wall 2 R-Value': '13',
#   'Wall 2 Insulation Type': 'EPS',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '60',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Roof 2 Type': 'Unvented',
#   'Roof 2 R-Value': '43',
#   'Roof 2 Insulation Type': 'PolyIso',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '32',
#   'Floor 1 Insulation Type': 'EPS',
#   'Floor Type 2': 'Basement Slab',
#   'Floor 2 R-Value': '16',
#   'Floor 2 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Sanford Hills',
#   'Window Product Name 1': 'Fixed w/CG 70/36 + 70/36',
#   'Whole Window U-Value 1': '0.2',
#   'Window Glazing SHGC 1': '0.34',
#   'Window Manufacturer 2': 'Sanford Hills',
#   'Window Product Name 2': 'Casement w/ CG 70/36 + 70/36',
#   'Whole Window U-Value 2': '0.2',
#   'Window Glazing SHGC 2': '0.34',
#   'Window Manufacturer 3': 'Kawneer',
#   'Window Product Name 3': 'Trifab Storefront with Solarban60',
#   'Whole Window U-Value 3': '0.36',
#   'Window Glazing SHGC 3': '0.39',
#   'Whole Door U-Value': '0.15',
#   'Ventilation System Manufacturer': 'Mitsubishi',
#   'Ventilation System Product Name': 'LGH-F470RX',
#   'Ventilation System Layout': 'Semi-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '71',
#   'Latent Recovery Efficiency': '40',
#   'Measured Ventilation Fan Efficiency': '0.78',
#   'Heating System Manufacturer': 'Daikin',
#   'Heating System Product Name': 'RXYQ96TATJU',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Daikin',
#   'Cooling System Product Name': 'RXYQ96TATJU',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Rinnai',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Natural Gas Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '15000',
#   'Renewable Energy System Size': '11'},
#  'Silvergreen': {'link': 'https://www.phius.org/certified-project-database/silvergreen',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '8456 sq. ft.',
#   'Construction Completion': '2019',
#   'Floor area': 8456.0,
#   'Phius Certified Verifier': 'Angela Iraldi',
#   'Phius CPHC (Secondary)': 'Joseph Holloway',
#   'Phius CPHC (Lead)': 'Tiffany Rolfing',
#   'Project Submitter': 'David Salamon',
#   'Construction Company': 'Custom Residential Construction / Hugh Lofting High Performance Homes',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '2',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018',
#   'All Electric': 'Yes',
#   'Design Certification': 'October 28, 2019',
#   'Final Certification': 'March 18, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.93',
#   'Annual Cooling Demand': '2.78',
#   'Peak Heating Load': '3.69',
#   'Peak Cooling Load': '1.57',
#   'Site Energy Use Index (EUI)': '9.57',
#   'Site Energy Use Index (w/Renewables)': '-0.52',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8300',
#   'Air Tightness (per enclosure area)': '0.056',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '37',
#   'Wall 1 Insulation Type': 'Fiberboard, Cellulose',
#   'Wall 2 Type': 'Insulated Concrete Form (ICF)',
#   'Wall 2 R-Value': '41',
#   'Wall 2 Insulation Type': 'EPS',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '79',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Roof 2 Type': 'Unvented',
#   'Roof 2 R-Value': '20',
#   'Roof 2 Insulation Type': 'EPS',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '24',
#   'Floor 1 Insulation Type': 'Mineral Wool',
#   'Window Manufacturer 1': 'Zola',
#   'Window Product Name 1': 'Thermoclad PLUS Tilt and Turn',
#   'Whole Window U-Value 1': '0.15',
#   'Window Glazing SHGC 1': '0.5',
#   'Window Manufacturer 2': 'Zola',
#   'Window Product Name 2': 'ThermoWood Fixed',
#   'Whole Window U-Value 2': '0.17',
#   'Window Frame Material 2': 'Wood',
#   'Window Glazing SHGC 2': '0.5',
#   'Window Manufacturer 3': 'Zola',
#   'Window Product Name 3': 'Thermowood Terrace Door',
#   'Whole Window U-Value 3': '0.17',
#   'Window Glazing SHGC 3': '0.5',
#   'Door Manufacturer': 'Zola',
#   'Door Product Name': 'ThermoWood Door',
#   'Whole Door U-Value': '0.17',
#   'Ventilation System Manufacturer': 'Zehnder',
#   'Ventilation System Product Name': 'ComfoAir Q600',
#   'Ventilation System Layout': 'De-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '80',
#   'Latent Recovery Efficiency': '68',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Rheem',
#   'Hot Water System Product Name': 'PROPH65',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'Community Solar',
#   'Renewable Energy Annual Production': '25000'},
#  'Tenney Residence': {'link': 'https://www.phius.org/certified-project-database/tenney-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '3450 sq. ft.',
#   'Floor area': 3450.0,
#   'Phius CPHC (Secondary)': 'Thomas Candee',
#   'Phius Certified Rater': 'David Brach',
#   'Project Submitter': 'David Brach',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'February 21, 2022',
#   'Final Certification': 'March 4, 2022',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '5.91',
#   'Annual Cooling Demand': '1.8',
#   'Peak Heating Load': '3.45',
#   'Peak Cooling Load': '1.29',
#   'Site Energy Use Index (EUI)': '9.81',
#   'Site Energy Use Index (w/Renewables)': '-3.1',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5553',
#   'HERS Rating w/Renewables': '-6',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Wall 1 Type': 'Exterior Load Bearing Double-Stud',
#   'Wall 1 R-Value': '40',
#   'Wall 1 Insulation Type': 'Fiberglass',
#   'Wall 2 Type': 'Other',
#   'Wall 2 R-Value': '33',
#   'Wall 2 Insulation Type': 'EPS, Fiberglass',
#   'Roof 1 Type': 'Unvented Roof',
#   'Roof 1 R-Value': '61',
#   'Roof 1 Insulation Type': 'EPS, Fiberglass',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '20',
#   'Floor 1 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Alpen',
#   'Window Product Name 1': 'Tyrol Series 9 Balanced Tilt Turn',
#   'Whole Window U-Value 1': '0.14',
#   'Window Glazing SHGC 1': '0.33',
#   'Window Manufacturer 2': 'Alpen',
#   'Window Product Name 2': 'Tyrol Series 9 Balanced Fixed',
#   'Whole Window U-Value 2': '0.14',
#   'Window Glazing SHGC 2': '0.33',
#   'Window Manufacturer 3': 'Alpen',
#   'Window Product Name 3': 'Alpen Tyrol Series 9 Balanced Swing Door "Standard"',
#   'Whole Window U-Value 3': '0.16',
#   'Window Glazing SHGC 3': '0.33',
#   'Ventilation System Manufacturer': 'UltimateAir',
#   'Ventilation System Product Name': 'RecoupAerator 200DX',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'HRV',
#   'Sensible Recovery Efficiency': '82',
#   'Measured Ventilation Fan Efficiency': '0.29',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Stiebel Eltron',
#   'Hot Water System Product Name': 'Accelera 300E',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '13048',
#   'Renewable Energy System Size': '9'},
#  'Lam Residence': {'link': 'https://www.phius.org/certified-project-database/lam-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1473 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 1473.0,
#   'Phius Certified Rater': 'Michael Browne',
#   'Phius CPHC (Lead)': 'Jordan Goldman',
#   'Project Submitter': 'Jordan Goldman',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Adams + Beasley Associates',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 12, 2020',
#   'Final Certification': 'February 18, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '9.74',
#   'Annual Cooling Demand': '2.08',
#   'Peak Heating Load': '7.08',
#   'Peak Cooling Load': '2.99',
#   'Site Energy Use Index (EUI)': '16.11',
#   'Site Energy Use Index (w/Renewables)': '-3.83',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6489',
#   'HERS Rating': '26',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '34',
#   'Wall 1 Insulation Type': 'Fiberboard, Cellulose',
#   'Roof 1 Type': 'Vented Above Deck',
#   'Roof 1 R-Value': '63',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '27',
#   'Floor 1 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Schuco',
#   'Window Product Name 1': 'Living MD (Fixed)',
#   'Whole Window U-Value 1': '0.13',
#   'Window Glazing SHGC 1': '0.54',
#   'Window Manufacturer 2': 'Schuco',
#   'Window Product Name 2': 'Living MD (Operable)',
#   'Whole Window U-Value 2': '0.13',
#   'Window Glazing SHGC 2': '0.54',
#   'Window Manufacturer 3': 'Schuco',
#   'Window Product Name 3': 'Living Slide',
#   'Whole Window U-Value 3': '0.17',
#   'Window Glazing SHGC 3': '0.54',
#   'Whole Door U-Value': '0.17',
#   'Ventilation System Manufacturer': 'Zehnder',
#   'Ventilation System Product Name': 'Comfair Q350',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '86',
#   'Latent Recovery Efficiency': '73',
#   'Measured Ventilation Fan Efficiency': '0.17',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Product Name': 'SUZ-KA18NAHZ',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Heating System Rating': 'COP',
#   'Heating System Performance (COP)': '3',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Product Name': 'SUZ-KA18NAHZ',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Cooling System Rating': 'EER',
#   'Cooling System Performance (EER)': '12.5',
#   'Hot Water System Manufacturer': 'Bradford',
#   'Hot Water System Product Name': 'Aerotherm 65 gallon',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Hot Water System Rating': 'Energy Factor (EF)',
#   'Hot Water System Performance Rating': '3.58',
#   'Range Hood Type': 'Exhaust',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '8607',
#   'Renewable Energy System Size': '6.8'},
#  'Theresa Passive House': {'link': 'https://www.phius.org/certified-project-database/theresa-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Addition',
#   'ASHRAE Climate Zone': '2A - Hot - Humid',
#   'INT. Conditioned Floor Area': '2218 sq. ft.',
#   'Floor area': 2218.0,
#   'Phius CPHC (Lead)': 'Nick Calcagni',
#   'Project Submitter': 'Trey Farmer',
#   'Construction Company': 'CleanTag LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'April 6, 2021',
#   'Final Certification': 'February 4, 2022',
#   'Region': 'South Central',
#   'Annual Heating Demand': '2.9',
#   'Annual Cooling Demand': '12.07',
#   'Peak Heating Load': '5.58',
#   'Peak Cooling Load': '3.73',
#   'Site Energy Use Index (EUI)': '12.66',
#   'Site Energy Use Index (w/Renewables)': '-1.76',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6459',
#   'Air Tightness (per enclosure area)': '0.036',
#   'Measured Ventilation Fan Efficiency': '0.8'},
#  'Sunset Residence': {'link': 'https://www.phius.org/certified-project-database/sunset-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1645 sq. ft.',
#   'Floor area': 1645.0,
#   'Phius CPHC (Secondary)': 'Bruce Friedman',
#   'Phius CPHC (Lead)': 'Karan Gupta',
#   'Project Submitter': 'Meghan Hanson',
#   'Building Owner': 'Michael Sylvester & Meghan Hanson',
#   'Construction Company': 'Hone Architects& Builders',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'October 22, 2020',
#   'Final Certification': 'January 12, 2022',
#   'Region': 'North Central',
#   'Annual Heating Demand': '12.15',
#   'Annual Cooling Demand': '6.15',
#   'Peak Heating Load': '8.58',
#   'Peak Cooling Load': '3.49',
#   'Site Energy Use Index (EUI)': '18.3',
#   'Site Energy Use Index (w/Renewables)': '-0.99',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8234',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Red Clay Creek': {'link': 'https://www.phius.org/certified-project-database/red-clay-creek',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '2898 sq. ft.',
#   'Floor area': 2898.0,
#   'Phius Certified Rater': 'David Berg',
#   'Phius CPHC (Secondary)': 'Kelly Fordice',
#   'Phius CPHC (Lead)': 'Paula Loomis',
#   'Project Submitter': 'Ilka Cassidy',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Hugh Lofting High Performance Building/ Holzraum System LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 6, 2019',
#   'Final Certification': 'December 23, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '6.16',
#   'Annual Cooling Demand': '2.36',
#   'Peak Heating Load': '4.43',
#   'Peak Cooling Load': '1.81',
#   'Site Energy Use Index (EUI)': '10.64',
#   'Site Energy Use Index (w/Renewables)': '-3.2',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6327',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.4'},
#  'Pipsqueak': {'link': 'https://www.phius.org/certified-project-database/pipsqueak',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1738 sq. ft.',
#   'Floor area': 1738.0,
#   'Phius CPHC (Lead)': 'Eric Davenport',
#   'Project Submitter': 'Thomas Candee',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Domain LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'September 27, 2019',
#   'Final Certification': 'December 23, 2021',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '4.96',
#   'Annual Cooling Demand': '2.78',
#   'Peak Heating Load': '3.88',
#   'Peak Cooling Load': '2.77',
#   'Site Energy Use Index (EUI)': '13.12',
#   'Site Energy Use Index (w/Renewables)': '8.54',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5279',
#   'Source Energy (Residential w/Renewables)': '3389',
#   'Air Tightness (per enclosure area)': '0.032',
#   'Measured Ventilation Fan Efficiency': '1'},
#  '11 Crown Street - Colony Street Townhomes': {'link': 'https://www.phius.org/certified-project-database/11-crown-street-colony-street-townhomes',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '12288 sq. ft.',
#   'Floor area': 12288.0,
#   'Phius Certified Verifier': 'Karla Butterfield',
#   'Phius CPHC (Lead)': 'Samina Iqbal',
#   'Project Submitter': 'Thomas Moore',
#   'Secondary Reviewer': 'Lisa White',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'The Michaels Organization',
#   'Number of Units': '8',
#   'Number of Stories': '3',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'August 27, 2018',
#   'Final Certification': 'November 23, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '4.72',
#   'Annual Cooling Demand': '0.7',
#   'Peak Heating Load': '3.85',
#   'Peak Cooling Load': '1.8',
#   'Site Energy Use Index (EUI)': '16.01',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '4715',
#   'Air Tightness (per enclosure area)': '0.064',
#   'Measured Ventilation Fan Efficiency': '0.4'},
#  'Westbrook Village Phase 2 - Building 12': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-12',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '9946 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 9946.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 15, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.35',
#   'Annual Cooling Demand': '1.93',
#   'Peak Heating Load': '4.02',
#   'Peak Cooling Load': '2.72',
#   'Site Energy Use Index (EUI)': '20.65',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '4900',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Measured Ventilation Fan Efficiency': '0.2'},
#  'Westbrook Village Phase 2 - Building 11': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-11',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10704 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 10704.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 15, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.47',
#   'Annual Cooling Demand': '2.32',
#   'Peak Heating Load': '4.16',
#   'Peak Cooling Load': '2.98',
#   'Site Energy Use Index (EUI)': '21.72',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5705',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.7'},
#  'Westbrook Village Phase 2 - Building 10': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-10',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '13748 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 13748.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '12',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '4.29',
#   'Annual Cooling Demand': '1.75',
#   'Peak Heating Load': '3.59',
#   'Peak Cooling Load': '2.44',
#   'Site Energy Use Index (EUI)': '19.3',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5361',
#   'Air Tightness (per enclosure area)': '0.047',
#   'Measured Ventilation Fan Efficiency': '0.6'},
#  'Westbrook Village Phase 2 - Building 09': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-09',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '6836 sq. ft.',
#   'Floor area': 6836.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.38',
#   'Annual Cooling Demand': '1.93',
#   'Peak Heating Load': '4.18',
#   'Peak Cooling Load': '2.73',
#   'Site Energy Use Index (EUI)': '20.28',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5576',
#   'Air Tightness (per enclosure area)': '0.043',
#   'Measured Ventilation Fan Efficiency': '0.5'},
#  'Westbrook Village Phase 2 - Building 08': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-08',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10378 sq. ft.',
#   'Floor area': 10378.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '12',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.08',
#   'Annual Cooling Demand': '1.09',
#   'Peak Heating Load': '3.74',
#   'Peak Cooling Load': '1.83',
#   'Site Energy Use Index (EUI)': '18.84',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6164',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Measured Ventilation Fan Efficiency': '0.5'},
#  'Westbrook Village Phase 2 - Building 07': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-07',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '8647 sq. ft.',
#   'Floor area': 8647.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.16',
#   'Annual Cooling Demand': '1.44',
#   'Peak Heating Load': '3.92',
#   'Peak Cooling Load': '2.21',
#   'Site Energy Use Index (EUI)': '19.6',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6464',
#   'Air Tightness (per enclosure area)': '0.05',
#   'Measured Ventilation Fan Efficiency': '0.7'},
#  'Maple Corner Passive House': {'link': 'https://www.phius.org/certified-project-database/maple-corner-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1288 sq. ft.',
#   'Floor area': 1288.0,
#   'Phius Certified Rater': 'Karen Bushey',
#   'Phius CPHC (Secondary)': 'Matt Fletcher',
#   'Phius CPHC (Lead)': 'Allen Brown',
#   'Project Submitter': 'Christopher Clarke Miksic',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Meg and John Dawkins',
#   'Construction Company': 'Montpelier Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 27, 2019',
#   'Final Certification': 'November 1, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '9.4',
#   'Annual Cooling Demand': '1.37',
#   'Peak Heating Load': '5.99',
#   'Peak Cooling Load': '2.4',
#   'Site Energy Use Index (EUI)': '15.61',
#   'Site Energy Use Index (w/Renewables)': '-5.09',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5498',
#   'Air Tightness (per enclosure area)': '0.028',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Hom Hanan House': {'link': 'https://www.phius.org/certified-project-database/hom-hanan-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '1819 sq. ft.',
#   'Floor area': 1819.0,
#   'Phius CPHC (Lead)': 'Douglas Rand',
#   'Project Submitter': 'Edwin May',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Joe Hom & Daniel Hanan',
#   'Construction Company': 'Cross Builders',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'January 4, 2021',
#   'Final Certification': 'October 8, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '7.09',
#   'Annual Cooling Demand': '2.88',
#   'Peak Heating Load': '5.12',
#   'Peak Cooling Load': '2.61',
#   'Site Energy Use Index (EUI)': '11.95',
#   'Site Energy Use Index (w/Renewables)': '4.56',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5947',
#   'Source Energy (Residential w/Renewables)': '2271',
#   'Air Tightness (per enclosure area)': '0.037',
#   'Measured Ventilation Fan Efficiency': '0.4',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Anthony Wayne III': {'link': 'https://www.phius.org/certified-project-database/anthony-wayne-iii',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '39806 sq. ft.',
#   'Construction Completion': '2017',
#   'Floor area': 39806.0,
#   'Phius Certified Rater': 'Brian Stanfill',
#   'Phius CPHC (Lead)': 'John Semmelhack',
#   'Project Submitter': 'John Semmelhack',
#   'Building Owner': 'Elon Development Company',
#   'Number of Units': '45',
#   'Number of Stories': '3',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'May 16, 2017',
#   'Final Certification': 'October 6, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '3.33',
#   'Annual Cooling Demand': '5.19',
#   'Peak Heating Load': '3.18',
#   'Peak Cooling Load': '2.65',
#   'Site Energy Use Index (EUI)': '21.69',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6214',
#   'Air Tightness (per enclosure area)': '0.048',
#   'Measured Ventilation Fan Efficiency': '0.6'},
#  '1300 Pike': {'link': 'https://www.phius.org/certified-project-database/1300-pike',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '29490 sq. ft.',
#   'Construction Completion': '2016',
#   'Floor area': 29490.0,
#   'Phius Certified Verifier': 'Greta Tjeltveit',
#   'Phius Certified Rater': 'Greta Tjeltveit',
#   'Phius CPHC (Lead)': 'Paul Knight',
#   'Project Submitter': 'Daniel Luddy',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Solis Seattle, LLC',
#   'Construction Company': 'Cascade Built',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '45',
#   'Number of Stories': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 6, 2019',
#   'Final Certification': 'September 27, 2021',
#   'Region': 'Northwest',
#   'Annual Heating Demand': '3.03',
#   'Annual Cooling Demand': '1',
#   'Peak Heating Load': '3.47',
#   'Peak Cooling Load': '1.81',
#   'Site Energy Use Index (EUI)': '27.59',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6075',
#   'Air Tightness (per enclosure area)': '0.05',
#   'Measured Ventilation Fan Efficiency': '1.5'},
#  'Fortin Residence': {'link': 'https://www.phius.org/certified-project-database/fortin-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1019 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 1019.0,
#   'Phius CPHC (Lead)': 'Junko Iwasaki',
#   'Project Submitter': 'James Mustillo',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Company': 'GO Logic LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'February 2, 2021',
#   'Final Certification': 'September 13, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '10.22',
#   'Annual Cooling Demand': '2.19',
#   'Peak Heating Load': '7.7',
#   'Peak Cooling Load': '2.49',
#   'Site Energy Use Index (EUI)': '22.54',
#   'Site Energy Use Index (w/Renewables)': '6.44',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6284',
#   'Source Energy (Residential w/Renewables)': '1796',
#   'Air Tightness (per enclosure area)': '0.033',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Northbrook Park District Activity Center': {'link': 'https://www.phius.org/certified-project-database/northbrook-park-district-activity-center',
#   'Status': 'Final Certified',
#   'Building Function': 'Government / Public',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44048 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 44048.0,
#   'Phius Certified Verifier': 'Lindsey Elton',
#   'Phius CPHC (Secondary)': 'Daniel Razzano',
#   'Phius CPHC (Lead)': 'Zhongdi Chen',
#   'Project Submitter': 'Zhongdi Chen',
#   'Secondary Reviewer': 'Lisa White',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Type': 'Insulated Concrete Form (ICF)',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'Design Certification': 'June 14, 2019',
#   'Final Certification': 'August 20, 2021',
#   'Region': 'Midwest',
#   'Annual Heating Demand': '3.9',
#   'Annual Cooling Demand': '3.36',
#   'Peak Heating Load': '4.85',
#   'Peak Cooling Load': '2.91',
#   'Site Energy Use Index (EUI)': '27.79',
#   'Site Energy Use Index (w/Renewables)': '22.16',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Non-Residential)': '71.92',
#   'Source Energy (Non-Residential w/Renewables)': '52.72',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '1.2',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Sonoran Desert Passive': {'link': 'https://www.phius.org/certified-project-database/sonoran-desert-passive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '2B - Hot - Dry',
#   'INT. Conditioned Floor Area': '2925 sq. ft.',
#   'Floor area': 2925.0,
#   'Phius Certified Rater': 'Michael Bestenlehner',
#   'Phius CPHC (Secondary)': 'Audrey Godwin',
#   'Phius CPHC (Lead)': 'Audrey Godwin',
#   'Project Submitter': 'David Brubaker',
#   'Primary Reviewer': 'Lisa White',
#   'Building Owner': 'David Brubaker',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'December 12, 2016',
#   'Final Certification': 'August 20, 2021',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '0.23',
#   'Annual Cooling Demand': '8.5',
#   'Peak Heating Load': '1.61',
#   'Peak Cooling Load': '3.32',
#   'Site Energy Use Index (EUI)': '12.02',
#   'Site Energy Use Index (w/Renewables)': '7.36',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8139',
#   'Source Energy (Residential w/Renewables)': '5200',
#   'Air Tightness (per enclosure area)': '0.027',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV'},
#  'Bowdoin College SCSC - LLC': {'link': 'https://www.phius.org/certified-project-database/bowdoin-college-scsc-llc',
#   'Status': 'Final Certified',
#   'Building Function': 'School / Education',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5373 sq. ft.',
#   'Floor area': 5373.0,
#   'Phius Certified Verifier': 'Gert Guldentops',
#   'Phius CPHC (Lead)': 'Oliver Baumann',
#   'Project Submitter': 'Elsa Mullin',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Bowdoin College',
#   'Construction Company': 'JF Scott Construction (Adam Lyons)',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   'Design Certification': 'November 6, 2020',
#   'Final Certification': 'August 4, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '10.5',
#   'Annual Cooling Demand': '2.33',
#   'Peak Heating Load': '7.66',
#   'Peak Cooling Load': '1.89',
#   'Site Energy Use Index (EUI)': '23.57',
#   'Site Energy Use Index (w/Renewables)': '14.62',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Non-Residential)': '59.07',
#   'Source Energy (Non-Residential w/Renewables)': '34',
#   'Air Tightness (per enclosure area)': '0.073',
#   'Measured Ventilation Fan Efficiency': '1.5',
#   'Renewable Energy Type(s)': 'RECs (Renewable Energy Certificates)'},
#  'Rose Lane Passive House': {'link': 'https://www.phius.org/certified-project-database/rose-lane-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1730 sq. ft.',
#   'Floor area': 1730.0,
#   'Phius Certified Rater': 'Marc Cregeur',
#   'Phius CPHC (Secondary)': 'Alison Kwok',
#   'Phius CPHC (Lead)': 'Jeffrey Pelletier',
#   'Project Submitter': 'Jonathan Bean',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Building Owner': 'Alison Kwok',
#   'Construction Company': 'Paul Allen, Allen Co Design It! Build it!',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'October 7, 2020',
#   'Final Certification': 'August 4, 2021',
#   'Region': 'Northwest',
#   'Annual Heating Demand': '5.69',
#   'Annual Cooling Demand': '2.65',
#   'Peak Heating Load': '3.75',
#   'Peak Cooling Load': '3.25',
#   'Site Energy Use Index (EUI)': '21.23',
#   'Site Energy Use Index (w/Renewables)': '15.13',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '7535',
#   'Source Energy (Residential w/Renewables)': '5371',
#   'Air Tightness (per enclosure area)': '0.057',
#   'Facade Type': 'Fiber Cement',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '25',
#   'Wall 1 Insulation Type': 'Fiberglass, Mineral Wool',
#   'Wall 2 Type': 'Other',
#   'Wall 2 R-Value': '25',
#   'Wall 2 Insulation Type': 'XPS, Fiberglass',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '104',
#   'Roof 1 Insulation Type': 'Fiberglass',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '25',
#   'Floor 1 Insulation Type': 'EPS',
#   'Floor Type 2': 'Overhang Floor',
#   'Floor 2 R-Value': '55',
#   'Floor 2 Insulation Type': 'Fiberglass',
#   'Window Manufacturer 1': 'Zola',
#   'Window Product Name 1': 'Thermo uPVC',
#   'Whole Window U-Value 1': '0.16',
#   'Window Frame Material 1': 'Unplasticized Polyvinyl Chloride (uPVC)',
#   'Window Glazing SHGC 1': '0.5',
#   'Ventilation System Manufacturer': 'Minotair',
#   'Ventilation System Product Name': 'PentaCare V12',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'Multifunction',
#   'Sensible Recovery Efficiency': '100',
#   'Measured Ventilation Fan Efficiency': '1',
#   'Heating System Manufacturer': 'Minotair',
#   'Heating System Product Name': 'PentaCare V12',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Heating System Rating': 'COP',
#   'Heating System Performance (COP)': '3',
#   'Cooling System Manufacturer': 'Minotair',
#   'Cooling System Product Name': 'PentaCare V12',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Cooling System Rating': 'EER',
#   'Cooling System Performance Rating': '11.4',
#   'Hot Water System Manufacturer': 'Bradford White',
#   'Hot Water System Product Name': 'Upright 50 gal',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Electric Water Heater',
#   'Hot Water System Rating': 'Uniform Energy Factor (UEF)',
#   'Hot Water System Performance Rating': '0.92',
#   'Range Hood Type': 'Exhaust',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '3091',
#   'Renewable Energy System Size': '3.9'},
#  'Mapes Apartments': {'link': 'https://www.phius.org/certified-project-database/mapes-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '29879 sq. ft.',
#   'Floor area': 29879.0,
#   'Phius CPHC (Lead)': 'Rebekah Shoup',
#   'Project Submitter': 'David Berger',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Type': 'Masonry',
#   'Number of Units': '30',
#   'Number of Stories': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'July 1, 2019',
#   'Final Certification': 'July 8, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '3.31',
#   'Annual Cooling Demand': '4.87',
#   'Peak Heating Load': '3.85',
#   'Peak Cooling Load': '2.42',
#   'Site Energy Use Index (EUI)': '27.69',
#   'Site Energy Use Index (w/Renewables)': '24.14',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6510',
#   'Source Energy (Residential w/Renewables)': '5379',
#   'Air Tightness (per enclosure area)': '0.11',
#   'Measured Ventilation Fan Efficiency': '1.1'},
#  'Stonebridge Senior Housing Phase 2': {'link': 'https://www.phius.org/certified-project-database/stonebridge-senior-housing-phase-2',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55698 sq. ft.',
#   'Floor area': 55698.0,
#   'Phius Certified Verifier': 'Michael Merck',
#   'Phius CPHC (Lead)': 'John Semmelhack',
#   'Project Submitter': 'John Semmelhack',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Stonebridge Senior Housing II, L.P.',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '50',
#   'Number of Stories': '4',
#   'Program Version': 'PHIUS+ 2015',
#   'All Electric': 'Yes',
#   'Design Certification': 'March 27, 2019',
#   'Final Certification': 'July 1, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '3.51',
#   'Annual Cooling Demand': '0.8',
#   'Peak Heating Load': '3.74',
#   'Peak Cooling Load': '1.53',
#   'Site Energy Use Index (EUI)': '15.75',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6063',
#   'Air Tightness (per enclosure area)': '0.046',
#   'Measured Ventilation Fan Efficiency': '0.8'},
#  'Olive Passive House': {'link': 'https://www.phius.org/certified-project-database/olive-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1484 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 1484.0,
#   'Phius Certified Rater': 'Troy Hodas',
#   'Phius CPHC (Lead)': 'Aaron Reed',
#   'Project Submitter': "Owen O'Connor",
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Alessandro Ronfini',
#   'Construction Company': 'Threshold Builders',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 12, 2020',
#   'Final Certification': 'June 30, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '9.22',
#   'Annual Cooling Demand': '3.82',
#   'Peak Heating Load': '6.53',
#   'Peak Cooling Load': '3.36',
#   'Site Energy Use Index (EUI)': '18.13',
#   'Site Energy Use Index (w/Renewables)': '10.72',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5521',
#   'Source Energy (Residential w/Renewables)': '3263',
#   'Air Tightness (per enclosure area)': '0.019',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'Community Solar'},
#  'Muncy Greene (w/ Community Space)': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-w-community-space',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
# ...
#   'Number of Units': '1',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'EverDry Toledo Office': {'link': 'https://www.phius.org/certified-project-database/everdry-toledo-office',
#   'Status': 'Registered',
#   'Phius CPHC (Lead)': 'Nicole Rusk',
#   'Project Submitter': 'Nicole Rusk',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Midwest',
#   'Compliance Software': 'WUFI Passive'},
#  'Riverton Park': {'link': 'https://www.phius.org/certified-project-database/riverton-park',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Phius CPHC (Lead)': 'Elsa Mullin',
#   'Project Submitter': 'Elsa Mullin',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Walnut Street Apartments': {'link': 'https://www.phius.org/certified-project-database/walnut-street-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Phius CPHC (Lead)': 'Christopher Briley',
#   'Project Submitter': 'Christopher Briley',
#   'Primary Reviewer': 'John Loercher',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 11': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-11',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6900 sq. ft.',
#   'Floor area': 6900.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': '',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 10': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-10',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 9': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-9',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 8': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-8',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 7': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-7',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 6': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-6',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6225 sq. ft.',
#   'Floor area': 6225.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'John Loercher',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 5': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6225 sq. ft.',
#   'Floor area': 6225.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Ryan Abendroth',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 4': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-4',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '4800 sq. ft.',
#   'Floor area': 4800.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 3': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-3',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 2': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-2',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'MLK / Tyler Street Building 1': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  '340 Dixwell Building Two': {'link': 'https://www.phius.org/certified-project-database/340-dixwell-building-two',
#   'Status': 'Registered',
#   'Phius CPHC (Lead)': 'Paul Selnau',
#   'Project Submitter': 'Paul Selnau',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Environmental Charter School - High School': {'link': 'https://www.phius.org/certified-project-database/environmental-charter-school-high-school',
#   'Status': 'Registered',
#   'Phius CPHC (Lead)': 'Craig Stevenson',
#   'Project Submitter': 'Craig Stevenson',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Vaughan Residence': {'link': 'https://www.phius.org/certified-project-database/vaughan-residence',
#   'Status': 'Registered',
#   'Construction Completion': '2022',
#   'Phius CPHC (Lead)': 'Peter Schmelzer',
#   'Project Submitter': 'Peter Schmelzer',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Compliance Software': 'WUFI Passive'},
#  'Residences on the Charles': {'link': 'https://www.phius.org/certified-project-database/residences-charles',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45155 sq. ft.',
#   'Floor area': 45155.0,
#   'Phius CPHC (Lead)': 'Thomas Secondo',
#   'Project Submitter': 'Thomas Secondo',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Callahan Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '38',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.06'},
#  'Montecito Casa Pasiva': {'link': 'https://www.phius.org/certified-project-database/montecito-casa-pasiva',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '3C - Warm - Marine',
#   'INT. Conditioned Floor Area': '4482 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 4482.0,
#   'Phius CPHC (Lead)': 'Ilka Cassidy',
#   'Project Submitter': 'Ilka Cassidy',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Southwest',
#   'Compliance Software': 'WUFI Passive'},
#  'West Side Homes Sustainable Rehabilitation & Infill Housing - Rhode Island': {'link': 'https://www.phius.org/certified-project-database/west-side-homes-sustainable-rehabilitation-infill-housing-rhode-island',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '4614 sq. ft.',
#   'Floor area': 4614.0,
#   'Phius CPHC (Lead)': 'Michelle Tinner',
#   'Project Submitter': 'Michelle Tinner',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Company': 'PUSH Buffalo',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Brewster Woods Community Housing - Building 40': {'link': 'https://www.phius.org/certified-project-database/brewster-woods-community-housing-building-40',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '28296 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 28296.0,
#   'Phius CPHC (Lead)': 'Ken Neuhauser',
#   'Project Submitter': 'Ken Neuhauser',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Delphi Construction, Inc.',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '23',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'JP Federal - Building 5': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '73313 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 73313.0,
#   'Phius CPHC (Lead)': 'Maciej Konieczny',
#   'Project Submitter': 'Maciej Konieczny',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Consigli',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '40',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'JP Federal - Building 1': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '57899 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 57899.0,
#   'Phius CPHC (Lead)': 'Maciej Konieczny',
#   'Project Submitter': 'Maciej Konieczny',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Consigli',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '33',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Bunker Hill Housing - Phase 1 (Building M)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-m',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '106660 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 106660.0,
#   'Phius CPHC (Lead)': 'Daniel Perez',
#   'Project Submitter': 'Daniel Perez',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Bunker Hill Housing - Phase 1 (Building F)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-f',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '234654 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 234654.0,
#   'Phius CPHC (Lead)': 'Daniel Perez',
#   'Project Submitter': 'Daniel Perez',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  '337 Cumberland': {'link': 'https://www.phius.org/certified-project-database/337-cumberland',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55270 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 55270.0,
#   'Project Submitter': 'Kai Fast',
#   'Construction Company': 'Ledgewood Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '96',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.06'},
#  'McElwain Apartments': {'link': 'https://www.phius.org/certified-project-database/mcelwain-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44189 sq. ft.',
#   'Floor area': 44189.0,
#   'Phius CPHC (Lead)': 'Ashley Wisse',
#   'Project Submitter': 'Ashley Wisse',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'CC MPZ Main Street LLC',
#   'Construction Type': 'Wood Frame',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive'},
#  'Conservatory Apartments': {'link': 'https://www.phius.org/certified-project-database/conservatory-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '22848 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 22848.0,
#   'Phius CPHC (Lead)': 'Victor Rivera',
#   'Project Submitter': 'Victor Rivera',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'McShane Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '44',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Midwest',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.05'},
#  'Fairplay': {'link': 'https://www.phius.org/certified-project-database/fairplay',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7B - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '1155 sq. ft.',
#   'Floor area': 1155.0,
#   'Project Submitter': 'Brian Fuentes',
#   'Construction Company': 'TBD',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2012',
#   'Region': 'North Central',
#   'Compliance Software': 'PHPP',
#   'Heating System Type': 'Electric Resistance'}}

# %%
len(all_projects)
# Out:
# 622

# %%
from geopy.geocoders import Nominatim
from bs4 import BeautifulSoup

geolocator = Nominatim(user_agent="PassiveHouseDatabaseHarvester")

# %%
geolocator.geocode("Narragansett, Rhode Island, USA")
# Out:
# Location(Narragansett, South County, Rhode Island, United States, (41.4501021, -71.4495005, 0.0))

# %%
geolocator.geocode("Somerville, MA, USA")
# Out:
# Location(Somerville, Middlesex County, Massachusetts, United States, (42.3875968, -71.0994968, 0.0))

# %% [raw]
# Skipping project Hawkins-Yurgalevitch Passive House - location not found Naragansett, Rhode Island
# Skipping project Schickler Lane ADU - location not found Belingham, Washington
# Skipping project 295 Painter Hill - location not found Wurtsburo, New York
# Skipping project Island Passive House - location not found Shaw Island, San Juan Islands, Washington
# Skipping project Brookfield Homes Passive House - location not found Unicorporated Adams County, Colorado
# Skipping project Casa Merlot - location not found Valle de Guadalupe, Ensenada, BC
# Skipping project Summer Park Phase 2 - location not found Hannover, New Hampshire
# Skipping project Summer Park - location not found Hannover, New Hampshire
# Skipping project Stone Ridge - Building A - location not found Springettbury, Pennsylvania
# Skipping project The Whisper House - location not found Barnegate, New Jersey
# Skipping project Esta bien (Clarence trust property) - location not found Lake Geneva (Jainsville/Rock County, WI climate data set), Wisconsin

# %%
https://www.phius.org/certified-project-database/hawkins-yurgalevitch-passive-house
    Naragansett, Rhode Island -> Narragansett, Rhode Island (double "r")
https://www.phius.org/certified-project-database/schickler-lane-adu
    Belingham, Washington -> Bellingham, Washington (double "l")
https://www.phius.org/certified-project-database/295-painter-hill
    Wurtsburo, New York -> Wurtsboro, New York ("o" instead of "u")
https://www.phius.org/certified-project-database/summer-park
    and
https://www.phius.org/certified-project-database/summer-park-phase-2
    Hannover, New Hampshire -> Hanover, New Hampshire (only one "n")
https://www.phius.org/certified-project-database/stone-ridge-building
    Springettbury, Pennsylvania -> Springettsbury, Pennsylvania (missing "s")
    note that the seplling is correct for building B in the same project: https://www.phius.org/certified-project-database/stone-ridge-building-b
https://www.phius.org/certified-project-database/whisper-house
    Barnegate, New Jersey -> Barnegat, New Jersey (one "e" needs to be removed)
https://www.phius.org/certified-project-database/esta-bien-clarence-trust-property    
    Geneva (Jainsville/Rock County, WI climate data set), Wisconsin ->
    This one is in the "Geneva (Jainsville/Rock County, Wisconsin" but for some reaon
    the words "climate data set", and an extra "WI" also apprear in the location

# %%
import json

def add_misspelled_location(misspelled, correct):
    with open("data/known_coords.json", 'r') as f:
        known_locs = json.load(f)
        
    geoloc = geolocator.geocode(correct, timeout=10)
    print(f'Found: {geoloc}')
    if geoloc:
        locobj = {"type": "Point", "coordinates": [geoloc.longitude, geoloc.latitude]}
        known_locs[misspelled] = locobj
        
    with open("data/known_coords.json", 'w') as f:
        json.dump(known_locs, f, indent=2)

# %%
add_misspelled_location("Naragansett, Rhode Island", "Narragansett, Rhode Island")
# Out:
# Found: Narragansett, South County, Rhode Island, United States

# %%
add_misspelled_location("Belingham, Washington", "Bellingham, Washington")
# Out:
# Found: Bellingham, Whatcom County, Washington, 98225-3243, United States

# %%
add_misspelled_location("Wurtsburo, New York", "Wurtsboro, New York")
# Out:
# Found: Wurtsboro, Town of Mamakating, Sullivan County, New York, United States

# %%
add_misspelled_location("Unicorporated Adams County, Colorado", "Adams County, Colorado")
# Out:
# Found: Adams County, Colorado, United States

# %%
add_misspelled_location("Shaw Island, San Juan Islands, Washington", "Shaw Island, Washington")
# Out:
# Found: Shaw Island, San Juan County, Washington, 98280, United States

# %%
add_misspelled_location("Valle de Guadalupe, Ensenada, BC", "Valle de Guadalupe, Ensenada")
# Out:
# Found: Valle de Guadalupe, Ensenada, Municipio de Ensenada, Baja California, 22785, México

# %%
add_misspelled_location("Hannover, New Hampshire", "Hanover, New Hampshire")
# Out:
# Found: Hanover, Grafton County, New Hampshire, United States

# %%
add_misspelled_location("Springettbury, Pennsylvania", "Springettsbury, Pennsylvania")
# Out:
# Found: Springettsbury Township, York County, Pennsylvania, United States

# %%
add_misspelled_location("Barnegate, New Jersey", "Barnegat, New Jersey")
# Out:
# Found: Barnegat, Barnegat Township, Ocean County, New Jersey, United States

# %%
add_misspelled_location("Lake Geneva (Jainsville/Rock County, WI climate data set), Wisconsin", 
                       "Geneva, Wisconsin")
# Out:
# Found: Lake Geneva, Walworth County, Wisconsin, United States

# %%
with open("data/PHIUS.json", 'r') as f:
        phius = json.load(f)

# %%
phius
# Out:
# {'Santaella Gardens': {'link': 'https://www.phius.org/certified-project-database/santaella-gardens',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '214543 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 214543.0},
#  'Oak Tree Village - Building A': {'link': 'https://www.phius.org/certified-project-database/oak-tree-village-building',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45195 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 45195.0},
#  'Silvergreen': {'link': 'https://www.phius.org/certified-project-database/silvergreen',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '8456 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 8456.0},
#  'Tenney Residence': {'link': 'https://www.phius.org/certified-project-database/tenney-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '3450 sq. ft.',
#   'Floor area': 3450.0},
#  'Lam Residence': {'link': 'https://www.phius.org/certified-project-database/lam-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1473 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1473.0},
#  'Theresa Passive House': {'link': 'https://www.phius.org/certified-project-database/theresa-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Addition',
#   'ASHRAE Climate Zone': '2A - Hot - Humid',
#   'INT. Conditioned Floor Area': '2218 sq. ft.',
#   'Floor area': 2218.0},
#  'Sunset Residence': {'link': 'https://www.phius.org/certified-project-database/sunset-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1645 sq. ft.',
#   'Floor area': 1645.0},
#  'Red Clay Creek': {'link': 'https://www.phius.org/certified-project-database/red-clay-creek',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '2898 sq. ft.',
#   'Floor area': 2898.0},
#  'Pipsqueak': {'link': 'https://www.phius.org/certified-project-database/pipsqueak',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1738 sq. ft.',
#   'Floor area': 1738.0},
#  '11 Crown Street - Colony Street Townhomes': {'link': 'https://www.phius.org/certified-project-database/11-crown-street-colony-street-townhomes',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '12288 sq. ft.',
#   'Floor area': 12288.0},
#  'Westbrook Village Phase 2 - Building 12': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-12',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '9946 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 9946.0},
#  'Westbrook Village Phase 2 - Building 11': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-11',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10704 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 10704.0},
#  'Westbrook Village Phase 2 - Building 10': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-10',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '13748 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 13748.0},
#  'Westbrook Village Phase 2 - Building 09': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-09',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '6836 sq. ft.',
#   'Floor area': 6836.0},
#  'Westbrook Village Phase 2 - Building 08': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-08',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10378 sq. ft.',
#   'Floor area': 10378.0},
#  'Westbrook Village Phase 2 - Building 07': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-07',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '8647 sq. ft.',
#   'Floor area': 8647.0},
#  'Maple Corner Passive House': {'link': 'https://www.phius.org/certified-project-database/maple-corner-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1288 sq. ft.',
#   'Floor area': 1288.0},
#  'Hom Hanan House': {'link': 'https://www.phius.org/certified-project-database/hom-hanan-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '1819 sq. ft.',
#   'Floor area': 1819.0},
#  'Anthony Wayne III': {'link': 'https://www.phius.org/certified-project-database/anthony-wayne-iii',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '39806 sq. ft.',
#   'Construction Completion': 2017,
#   'Floor area': 39806.0},
#  '1300 Pike': {'link': 'https://www.phius.org/certified-project-database/1300-pike',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '29490 sq. ft.',
#   'Construction Completion': 2016,
#   'Floor area': 29490.0},
#  'Fortin Residence': {'link': 'https://www.phius.org/certified-project-database/fortin-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1019 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 1019.0},
#  'Northbrook Park District Activity Center': {'link': 'https://www.phius.org/certified-project-database/northbrook-park-district-activity-center',
#   'Status': 'Final Certified',
#   'Building Function': 'Government / Public',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44048 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 44048.0},
#  'Sonoran Desert Passive': {'link': 'https://www.phius.org/certified-project-database/sonoran-desert-passive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '2B - Hot - Dry',
#   'INT. Conditioned Floor Area': '2925 sq. ft.',
#   'Floor area': 2925.0},
#  'Bowdoin College SCSC - LLC': {'link': 'https://www.phius.org/certified-project-database/bowdoin-college-scsc-llc',
#   'Status': 'Final Certified',
#   'Building Function': 'School / Education',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5373 sq. ft.',
#   'Floor area': 5373.0},
#  'Rose Lane Passive House': {'link': 'https://www.phius.org/certified-project-database/rose-lane-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1730 sq. ft.',
#   'Floor area': 1730.0},
#  'Mapes Apartments': {'link': 'https://www.phius.org/certified-project-database/mapes-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '29879 sq. ft.',
#   'Floor area': 29879.0},
#  'Stonebridge Senior Housing Phase 2': {'link': 'https://www.phius.org/certified-project-database/stonebridge-senior-housing-phase-2',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55698 sq. ft.',
#   'Floor area': 55698.0},
#  'Olive Passive House': {'link': 'https://www.phius.org/certified-project-database/olive-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1484 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1484.0},
#  'Muncy Greene (w/ Community Space)': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-w-community-space',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '7008 sq. ft.',
#   'Floor area': 7008.0},
#  'Main Street South Berwick ME 03908': {'link': 'https://www.phius.org/certified-project-database/main-street-south-berwick-me-03908',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '20290 sq. ft.',
#   'Floor area': 20290.0},
#  'Harrison Street Infill': {'link': 'https://www.phius.org/certified-project-database/harrison-street-infill',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '3650 sq. ft.',
#   'Floor area': 3650.0},
#  'Hawkins-Yurgalevitch Passive House': {'link': 'https://www.phius.org/certified-project-database/hawkins-yurgalevitch-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3749 sq. ft.',
#   'Floor area': 3749.0},
#  'Sugarbush House': {'link': 'https://www.phius.org/certified-project-database/sugarbush-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1427 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1427.0},
#  '[bundle] mobile office': {'link': 'https://www.phius.org/certified-project-database/bundle-mobile-office',
#   'Status': 'Final Certified',
#   'Building Function': 'Office',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '197 sq. ft.',
#   'Floor area': 197.0},
#  'Saltbox House': {'link': 'https://www.phius.org/certified-project-database/saltbox-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7A - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '2472 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 2472.0},
#  'Willrett Residence': {'link': 'https://www.phius.org/certified-project-database/willrett-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1847 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1847.0},
#  'Hook & Ladder': {'link': 'https://www.phius.org/certified-project-database/hook-ladder',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '53167 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 53167.0},
#  'Carroll Center Addition/Renovation': {'link': 'https://www.phius.org/certified-project-database/carroll-center-additionrenovation',
#   'Status': 'Final Certified',
#   'Building Function': 'School / Education',
#   'Project Type': 'Addition',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '7667 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 7667.0},
#  'Indwell McQuesten Lofts & Hamilton Public Library - Parkdale Branch': {'link': 'https://www.phius.org/certified-project-database/indwell-mcquesten-lofts-hamilton-public-library-parkdale-branch',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7A - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '31657 sq. ft.',
#   'Floor area': 31657.0},
#  '577 West 161st Street': {'link': 'https://www.phius.org/certified-project-database/577-west-161st-street',
#   'Status': 'Final Certified',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '16321 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 16321.0},
#  'Seminary Hill Ciders': {'link': 'https://www.phius.org/certified-project-database/seminary-hill-ciders',
#   'Status': 'Final Certified',
#   'Building Function': 'Other Non-Residential',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '7542 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 7542.0},
#  'Doig River Cultural Center': {'link': 'https://www.phius.org/certified-project-database/doig-river-cultural-center',
#   'Status': 'Final Certified',
#   'Building Function': 'Government / Public',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7A - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '5514 sq. ft.',
#   'Floor area': 5514.0},
#  'Foley Residence': {'link': 'https://www.phius.org/certified-project-database/foley-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1986 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1986.0},
#  'Ames Hill Passive': {'link': 'https://www.phius.org/certified-project-database/ames-hill-passive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1784 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1784.0},
#  'Finch Cambridge': {'link': 'https://www.phius.org/certified-project-database/finch-cambridge',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '101024 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 101024.0},
#  'VanDercreek Residence': {'link': 'https://www.phius.org/certified-project-database/vandercreek-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2902 sq. ft.',
#   'Construction Completion': 2017,
#   'Floor area': 2902.0},
#  'Pioneer Apartments': {'link': 'https://www.phius.org/certified-project-database/pioneer-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '42069 sq. ft.',
#   'Floor area': 42069.0},
#  'Yannell Passive House': {'link': 'https://www.phius.org/certified-project-database/yannell-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3884 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 3884.0},
#  'Columbia County Habitat Passive Townhomes 3': {'link': 'https://www.phius.org/certified-project-database/columbia-county-habitat-passive-townhomes-3',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2872 sq. ft.',
#   'Construction Completion': 2016,
#   'Floor area': 2872.0},
#  'Bertucci Pfundt Residence': {'link': 'https://www.phius.org/certified-project-database/bertucci-pfundt-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '2224 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 2224.0},
#  'Spice Residence': {'link': 'https://www.phius.org/certified-project-database/spice-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2104 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 2104.0},
#  'Parade Street Commons East - Building A': {'link': 'https://www.phius.org/certified-project-database/parade-street-commons-east-building',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '7603 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 7603.0},
#  'Parade Street Commons East - Building E': {'link': 'https://www.phius.org/certified-project-database/parade-street-commons-east-building-e',
#   'Status': 'Final Certified',
#   'Building Function': 'Other Non-Residential',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1035 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 1035.0},
#  'Parade Street Commons East - Building D': {'link': 'https://www.phius.org/certified-project-database/parade-street-commons-east-building-d',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '9737 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 9737.0},
#  'Parade Street Commons East - Building C': {'link': 'https://www.phius.org/certified-project-database/parade-street-commons-east-building-c',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '6120 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 6120.0},
#  'Parade Street Commons East - Building B': {'link': 'https://www.phius.org/certified-project-database/parade-street-commons-east-building-b',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '24554 sq. ft.',
#   'Floor area': 24554.0},
#  '542 W 153rd St': {'link': 'https://www.phius.org/certified-project-database/542-w-153rd-st',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '28707 sq. ft.',
#   'Construction Completion': 2017,
#   'Floor area': 28707.0},
#  '3221 Blenheim Place': {'link': 'https://www.phius.org/certified-project-database/3221-blenheim-place',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '2138 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 2138.0},
#  'North Miller Passive Multifamily': {'link': 'https://www.phius.org/certified-project-database/north-miller-passive-multifamily',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2354 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 2354.0},
#  'Wildwood Drive': {'link': 'https://www.phius.org/certified-project-database/wildwood-drive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3551 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 3551.0},
#  'Muncy Greene - Building 400': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-400',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 1000': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-1000',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 900': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-900',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 800': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-800',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 700': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-700',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 600': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-600',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 500': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-500',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 200': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-200',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Muncy Greene - Building 100': {'link': 'https://www.phius.org/certified-project-database/muncy-greene-building-100',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5533 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 5533.0},
#  'Park Row Residences - Building 4': {'link': 'https://www.phius.org/certified-project-database/park-row-residences-building-4',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '11651 sq. ft.',
#   'Floor area': 11651.0},
#  'Park Row Residences - Building 3': {'link': 'https://www.phius.org/certified-project-database/park-row-residences-building-3',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '11651 sq. ft.',
#   'Floor area': 11651.0},
#  'Park Row Residences - Building 1': {'link': 'https://www.phius.org/certified-project-database/park-row-residences-building-1',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '11651 sq. ft.',
#   'Floor area': 11651.0},
#  'Park Row Residences - Bowdoin College - Building 2': {'link': 'https://www.phius.org/certified-project-database/park-row-residences-bowdoin-college-building-2',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '12044 sq. ft.',
#   'Floor area': 12044.0},
#  'Ballard Passive': {'link': 'https://www.phius.org/certified-project-database/ballard-passive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '2184 sq. ft.',
#   'Floor area': 2184.0},
#  'Larson Passive House': {'link': 'https://www.phius.org/certified-project-database/larson-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2112 sq. ft.',
#   'Floor area': 2112.0},
#  'Beach Green Dunes Phase 2': {'link': 'https://www.phius.org/certified-project-database/beach-green-dunes-phase-2',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '103133 sq. ft.',
#   'Floor area': 103133.0},
#  'Provo Passive House': {'link': 'https://www.phius.org/certified-project-database/provo-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '6240 sq. ft.',
#   'Floor area': 6240.0},
#  'Afton Passive House': {'link': 'https://www.phius.org/certified-project-database/afton-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '4027 sq. ft.',
#   'Floor area': 4027.0},
#  'Tracy Community Housing': {'link': 'https://www.phius.org/certified-project-database/tracy-community-housing',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '26246 sq. ft.',
#   'Floor area': 26246.0},
#  '176 North Winooski Ave': {'link': 'https://www.phius.org/certified-project-database/176-north-winooski-ave',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1380 sq. ft.',
#   'Floor area': 1380.0},
#  'Loantaka': {'link': 'https://www.phius.org/certified-project-database/loantaka',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3981 sq. ft.',
#   'Floor area': 3981.0},
#  "St Joseph's School Addition": {'link': 'https://www.phius.org/certified-project-database/st-josephs-school-addition',
#   'Status': 'Final Certified',
#   'Building Function': 'School / Education',
#   'Project Type': 'Addition',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '7016 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 7016.0},
#  'Cascade Hudson Apartments': {'link': 'https://www.phius.org/certified-project-database/cascade-hudson-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '14813 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 14813.0},
#  'Meadows House': {'link': 'https://www.phius.org/certified-project-database/meadows-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '4490 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 4490.0},
#  'Wheaton College Dormitory': {'link': 'https://www.phius.org/certified-project-database/wheaton-college-dormitory',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '38186 sq. ft.',
#   'Floor area': 38186.0},
#  'Casa La Vista': {'link': 'https://www.phius.org/certified-project-database/casa-la-vista',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '2A - Hot - Humid',
#   'INT. Conditioned Floor Area': '2990 sq. ft.',
#   'Floor area': 2990.0},
#  'Crackatuxet Residence': {'link': 'https://www.phius.org/certified-project-database/crackatuxet-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1632 sq. ft.',
#   'Floor area': 1632.0},
#  'Edmonds Residence': {'link': 'https://www.phius.org/certified-project-database/edmonds-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2643 sq. ft.',
#   'Floor area': 2643.0},
#  'Palladino Cottage': {'link': 'https://www.phius.org/certified-project-database/palladino-cottage',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '560 sq. ft.',
#   'Floor area': 560.0},
#  'Coman Residence': {'link': 'https://www.phius.org/certified-project-database/coman-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2348 sq. ft.',
#   'Floor area': 2348.0},
#  'Fairwood Commons': {'link': 'https://www.phius.org/certified-project-database/fairwood-commons',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '56050 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 56050.0},
#  'Acorn Glade': {'link': 'https://www.phius.org/certified-project-database/acorn-glade',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1785 sq. ft.',
#   'Floor area': 1785.0},
#  'Flora Vista': {'link': 'https://www.phius.org/certified-project-database/flora-vista',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '2398 sq. ft.',
#   'Floor area': 2398.0},
#  'Roxbury Apartments': {'link': 'https://www.phius.org/certified-project-database/roxbury-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '43573 sq. ft.',
#   'Floor area': 43573.0},
#  'THOMPSON PASSIVE HOUSE': {'link': 'https://www.phius.org/certified-project-database/thompson-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '2279 sq. ft.',
#   'Floor area': 2279.0},
#  'Schickler Lane Ph': {'link': 'https://www.phius.org/certified-project-database/schickler-lane-ph',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '2532 sq. ft.',
#   'Floor area': 2532.0},
#  'Schickler Lane ADU': {'link': 'https://www.phius.org/certified-project-database/schickler-lane-adu',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1034 sq. ft.',
#   'Floor area': 1034.0},
#  'PH01': {'link': 'https://www.phius.org/certified-project-database/ph01',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2013 sq. ft.',
#   'Floor area': 2013.0},
#  '29 Bellis Circle': {'link': 'https://www.phius.org/certified-project-database/29-bellis-circle',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3366 sq. ft.',
#   'Floor area': 3366.0},
#  '1007 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1007-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '6990 sq. ft.',
#   'Floor area': 6990.0},
#  '1006 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1006-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '9274 sq. ft.',
#   'Floor area': 9274.0},
#  '1005 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1005-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '6990 sq. ft.',
#   'Floor area': 6990.0},
#  'CreekView Apartments at Woodland Park Phase 1 - Building 12': {'link': 'https://www.phius.org/certified-project-database/creekview-apartments-woodland-park-phase-1-building-12',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '6990 sq. ft.',
#   'Floor area': 6990.0},
#  '3005 CreekView Drive - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/3005-creekview-drive-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '5904 sq. ft.',
#   'Floor area': 5904.0},
#  '3004 Creekview Drive - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/3004-creekview-drive-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '9274 sq. ft.',
#   'Floor area': 9274.0},
#  '3001 CreekView Drive - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/3001-creekview-drive-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '5904 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 5904.0},
#  '1011 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1011-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '6990 sq. ft.',
#   'Floor area': 6990.0},
#  '3003 CreekView Drive - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/3003-creekview-drive-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '5904 sq. ft.',
#   'Floor area': 5904.0},
#  '1009 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1009-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '6990 sq. ft.',
#   'Floor area': 6990.0},
#  '3000 Creekview Drive - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/3000-creekview-drive-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '9274 sq. ft.',
#   'Floor area': 9274.0},
#  'Habitat 20K Passive House': {'link': 'https://www.phius.org/certified-project-database/habitat-20k-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '3A - Warm - Humid',
#   'INT. Conditioned Floor Area': '819 sq. ft.',
#   'Floor area': 819.0},
#  '1004 Woodland Park Circle - CreekView Apartments at Woodland Park': {'link': 'https://www.phius.org/certified-project-database/1004-woodland-park-circle-creekview-apartments-woodland-park',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '9274 sq. ft.',
#   'Floor area': 9274.0},
#  'Prairie Athletic & Recreation Center': {'link': 'https://www.phius.org/certified-project-database/prairie-athletic-recreation-center',
#   'Status': 'Final Certified',
#   'Building Function': 'Government / Public',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '35204 sq. ft.',
#   'Construction Completion': 2018,
#   'Floor area': 35204.0},
#  'South Jersey Passive House': {'link': 'https://www.phius.org/certified-project-database/south-jersey-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '2262 sq. ft.',
#   'Floor area': 2262.0},
#  'Preissner Residence': {'link': 'https://www.phius.org/certified-project-database/preissner-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '4990 sq. ft.',
#   'Floor area': 4990.0},
#  'Phantom Lake Passive House': {'link': 'https://www.phius.org/certified-project-database/phantom-lake-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '2790 sq. ft.',
#   'Floor area': 2790.0},
#  '295 Painter Hill': {'link': 'https://www.phius.org/certified-project-database/295-painter-hill',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1428 sq. ft.',
#   'Floor area': 1428.0},
#  'Madison Park Passive House': {'link': 'https://www.phius.org/certified-project-database/madison-park-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '3323 sq. ft.',
#   'Floor area': 3323.0},
#  'Bayside Anchor Apartments': {'link': 'https://www.phius.org/certified-project-database/bayside-anchor-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '36161 sq. ft.',
#   'Floor area': 36161.0},
#  'Polk Passive House': {'link': 'https://www.phius.org/certified-project-database/polk-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '2677 sq. ft.',
#   'Floor area': 2677.0},
#  'Tierra Linda': {'link': 'https://www.phius.org/certified-project-database/tierra-linda',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '8596 sq. ft.',
#   'Construction Completion': 2018,
#   'Floor area': 8596.0},
#  'Rockquist Passive House Minor': {'link': 'https://www.phius.org/certified-project-database/rockquist-passive-house-minor',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3680 sq. ft.',
#   'Construction Completion': 2019,
#   'Floor area': 3680.0},
#  'Contemporary Ocean View PEI': {'link': 'https://www.phius.org/certified-project-database/contemporary-ocean-view-pei',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '2568 sq. ft.',
#   'Floor area': 2568.0},
#  'Modern Ocean View PEI': {'link': 'https://www.phius.org/certified-project-database/modern-ocean-view-pei',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3470 sq. ft.',
#   'Floor area': 3470.0},
#  'Granite City Housing Authority Duplex Prototype': {'link': 'https://www.phius.org/certified-project-database/granite-city-housing-authority-duplex-prototype',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '1150 sq. ft.',
#   'Floor area': 1150.0},
#  'Park Avenue Green': {'link': 'https://www.phius.org/certified-project-database/park-avenue-green',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '152126 sq. ft.',
#   'Floor area': 152126.0},
#  'Duntourin Farm': {'link': 'https://www.phius.org/certified-project-database/duntourin-farm',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1682 sq. ft.',
#   'Floor area': 1682.0},
#  'Distillery North': {'link': 'https://www.phius.org/certified-project-database/distillery-north',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '27840 sq. ft.',
#   'Floor area': 27840.0},
#  'Bedford Passive House': {'link': 'https://www.phius.org/certified-project-database/bedford-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3432 sq. ft.',
#   'Construction Completion': 2016,
#   'Floor area': 3432.0},
#  'Jordan Passive House': {'link': 'https://www.phius.org/certified-project-database/jordan-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '3578 sq. ft.',
#   'Floor area': 3578.0},
#  'Gilford Village Knolls III': {'link': 'https://www.phius.org/certified-project-database/gilford-village-knolls-iii',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '20571 sq. ft.',
#   'Floor area': 20571.0},
#  'Adams Street Office': {'link': 'https://www.phius.org/certified-project-database/adams-street-office',
#   'Status': 'Final Certified',
#   'Building Function': 'Office',
#   'Project Type': 'Retrofit',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1255 sq. ft.',
#   'Floor area': 1255.0},
# ...
#   'Floor area': 45786.0},
#  'Clintonville Passive House': {'link': 'https://www.phius.org/certified-project-database/clintonville-passive-house',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'INT. Conditioned Floor Area': '1930 sq. ft.',
#   'Floor area': 1930.0},
#  'Depot Village': {'link': 'https://www.phius.org/certified-project-database/depot-village',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55078 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 55078.0},
#  'ZBrains Project': {'link': 'https://www.phius.org/certified-project-database/zbrains-project',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '3A - Warm - Humid',
#   'INT. Conditioned Floor Area': '23 sq. ft.',
#   'Construction Completion': 1990,
#   'Floor area': 23.0},
#  '4800 State Line': {'link': 'https://www.phius.org/certified-project-database/4800-state-line',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'INT. Conditioned Floor Area': '3477 sq. ft.',
#   'Floor area': 3477.0},
#  'Olsen Residence': {'link': 'https://www.phius.org/certified-project-database/olsen-residence',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'INT. Conditioned Floor Area': '6757 sq. ft.',
#   'Floor area': 6757.0},
#  'Front Street Building 5': {'link': 'https://www.phius.org/certified-project-database/front-street-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '38440 sq. ft.',
#   'Floor area': 38440.0},
#  'Queen Anne Passive': {'link': 'https://www.phius.org/certified-project-database/queen-anne-passive',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily'},
#  'SchreinerHaus': {'link': 'https://www.phius.org/certified-project-database/schreinerhaus',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family'},
#  'Mountain Park Passive': {'link': 'https://www.phius.org/certified-project-database/mountain-park-passive',
#   'Status': 'Registered'},
#  'Eplus Highland': {'link': 'https://www.phius.org/certified-project-database/eplus-highland',
#   'Status': 'Registered',
#   'INT. Conditioned Floor Area': '26907 sq. ft.',
#   'Floor area': 26907.0},
#  'North Ave Workforce Housing Building C': {'link': 'https://www.phius.org/certified-project-database/north-ave-workforce-housing-building-c',
#   'Status': 'Registered',
#   'INT. Conditioned Floor Area': '4367 sq. ft.',
#   'Floor area': 4367.0},
#  'Tillstrom House': {'link': 'https://www.phius.org/certified-project-database/tillstrom-house',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family'},
#  'Harmony House': {'link': 'https://www.phius.org/certified-project-database/harmony-house',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family'},
#  'Colombini Residence': {'link': 'https://www.phius.org/certified-project-database/colombini-residence',
#   'Status': 'Registered',
#   'INT. Conditioned Floor Area': '3526 sq. ft.',
#   'Floor area': 3526.0},
#  'Alexandra Park Phase 2 Site 16': {'link': 'https://www.phius.org/certified-project-database/alexandra-park-phase-2-site-16',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily'},
#  'Alexandra Park Phase 2 Site 3': {'link': 'https://www.phius.org/certified-project-database/alexandra-park-phase-2-site-3',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '8770 sq. ft.',
#   'Floor area': 8770.0},
#  'T5M Glenora 16 South Building': {'link': 'https://www.phius.org/certified-project-database/t5m-glenora-16-south-building',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily'},
#  'Ithaca Passive House': {'link': 'https://www.phius.org/certified-project-database/ithaca-passive-house',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family'},
#  '108 Centre Street': {'link': 'https://www.phius.org/certified-project-database/108-centre-street',
#   'Status': 'Registered',
#   'INT. Conditioned Floor Area': '50350 sq. ft.',
#   'Floor area': 50350.0},
#  'Faircliff Plaza East': {'link': 'https://www.phius.org/certified-project-database/faircliff-plaza-east',
#   'Status': 'Registered'},
#  'Yume House': {'link': 'https://www.phius.org/certified-project-database/yume-house',
#   'Status': 'Registered'},
#  '2 H Street': {'link': 'https://www.phius.org/certified-project-database/2-h-street',
#   'Status': 'Registered'},
#  'Mount Vernon Library Commons': {'link': 'https://www.phius.org/certified-project-database/mount-vernon-library-commons',
#   'Status': 'Registered'},
#  '27 Fairview Building B': {'link': 'https://www.phius.org/certified-project-database/27-fairview-building-b',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'INT. Conditioned Floor Area': '65785 sq. ft.',
#   'Floor area': 65785.0},
#  '27 Fairview Building A': {'link': 'https://www.phius.org/certified-project-database/27-fairview-building',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'INT. Conditioned Floor Area': '84915 sq. ft.',
#   'Floor area': 84915.0},
#  'North Ave Workforce Housing - Building B': {'link': 'https://www.phius.org/certified-project-database/north-ave-workforce-housing-building-b',
#   'Status': 'Registered'},
#  'Bardin Residence': {'link': 'https://www.phius.org/certified-project-database/bardin-residence',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'INT. Conditioned Floor Area': '5696 sq. ft.',
#   'Floor area': 5696.0},
#  'Dogwood Passive House': {'link': 'https://www.phius.org/certified-project-database/dogwood-passive-house',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family'},
#  '311 11th Ave E': {'link': 'https://www.phius.org/certified-project-database/311-11th-ave-e',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '29398 sq. ft.',
#   'Floor area': 29398.0},
#  '1177 Bushwick Ave': {'link': 'https://www.phius.org/certified-project-database/1177-bushwick-ave',
#   'Status': 'Registered'},
#  'Amethyst Brook': {'link': 'https://www.phius.org/certified-project-database/amethyst-brook',
#   'Status': 'Registered'},
#  'Wilber Residence': {'link': 'https://www.phius.org/certified-project-database/wilber-residence',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'INT. Conditioned Floor Area': '4500 sq. ft.',
#   'Floor area': 4500.0},
#  'EverDry Toledo Office': {'link': 'https://www.phius.org/certified-project-database/everdry-toledo-office',
#   'Status': 'Registered'},
#  'Riverton Park': {'link': 'https://www.phius.org/certified-project-database/riverton-park',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily'},
#  'Walnut Street Apartments': {'link': 'https://www.phius.org/certified-project-database/walnut-street-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily'},
#  'MLK / Tyler Street Building 11': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-11',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6900 sq. ft.',
#   'Floor area': 6900.0},
#  'MLK / Tyler Street Building 10': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-10',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0},
#  'MLK / Tyler Street Building 9': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-9',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0},
#  'MLK / Tyler Street Building 8': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-8',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0},
#  'MLK / Tyler Street Building 7': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-7',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0},
#  'MLK / Tyler Street Building 6': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-6',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6225 sq. ft.',
#   'Floor area': 6225.0},
#  'MLK / Tyler Street Building 5': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6225 sq. ft.',
#   'Floor area': 6225.0},
#  'MLK / Tyler Street Building 4': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-4',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '4800 sq. ft.',
#   'Floor area': 4800.0},
#  'MLK / Tyler Street Building 3': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-3',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0},
#  'MLK / Tyler Street Building 2': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-2',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0},
#  'MLK / Tyler Street Building 1': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0},
#  '340 Dixwell Building Two': {'link': 'https://www.phius.org/certified-project-database/340-dixwell-building-two',
#   'Status': 'Registered'},
#  'Environmental Charter School - High School': {'link': 'https://www.phius.org/certified-project-database/environmental-charter-school-high-school',
#   'Status': 'Registered'},
#  'Vaughan Residence': {'link': 'https://www.phius.org/certified-project-database/vaughan-residence',
#   'Status': 'Registered',
#   'Construction Completion': 2022},
#  'Residences on the Charles': {'link': 'https://www.phius.org/certified-project-database/residences-charles',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45155 sq. ft.',
#   'Floor area': 45155.0},
#  'Montecito Casa Pasiva': {'link': 'https://www.phius.org/certified-project-database/montecito-casa-pasiva',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '3C - Warm - Marine',
#   'INT. Conditioned Floor Area': '4482 sq. ft.',
#   'Construction Completion': 2022,
#   'Floor area': 4482.0},
#  'West Side Homes Sustainable Rehabilitation & Infill Housing - Rhode Island': {'link': 'https://www.phius.org/certified-project-database/west-side-homes-sustainable-rehabilitation-infill-housing-rhode-island',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '4614 sq. ft.',
#   'Floor area': 4614.0},
#  'Brewster Woods Community Housing - Building 40': {'link': 'https://www.phius.org/certified-project-database/brewster-woods-community-housing-building-40',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '28296 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 28296.0},
#  'JP Federal - Building 5': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '73313 sq. ft.',
#   'Construction Completion': 2022,
#   'Floor area': 73313.0},
#  'JP Federal - Building 1': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '57899 sq. ft.',
#   'Construction Completion': 2022,
#   'Floor area': 57899.0},
#  'Bunker Hill Housing - Phase 1 (Building M)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-m',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '106660 sq. ft.',
#   'Construction Completion': 2022,
#   'Floor area': 106660.0},
#  'Bunker Hill Housing - Phase 1 (Building F)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-f',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '234654 sq. ft.',
#   'Construction Completion': 2022,
#   'Floor area': 234654.0},
#  '337 Cumberland': {'link': 'https://www.phius.org/certified-project-database/337-cumberland',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55270 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 55270.0},
#  'McElwain Apartments': {'link': 'https://www.phius.org/certified-project-database/mcelwain-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44189 sq. ft.',
#   'Floor area': 44189.0},
#  'Conservatory Apartments': {'link': 'https://www.phius.org/certified-project-database/conservatory-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '22848 sq. ft.',
#   'Construction Completion': 2021,
#   'Floor area': 22848.0},
#  'West Don Ravine Home': {'link': 'https://www.phius.org/certified-project-database/west-don-ravine-home',
#   'Status': 'Design Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3737 sq. ft.',
#   'Construction Completion': 2020,
#   'Floor area': 3737.0},
#  '811 Gladstone': {'link': 'https://www.phius.org/certified-project-database/811-gladstone',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '90828 sq. ft.',
#   'Floor area': 90828.0},
#  'Fairplay': {'link': 'https://www.phius.org/certified-project-database/fairplay',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7B - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '1155 sq. ft.',
#   'Floor area': 1155.0},
#  'West Moberly Health Centre': {'link': 'https://www.phius.org/certified-project-database/west-moberly-health-centre',
#   'Status': 'Design Certified',
#   'Building Function': 'Other Non-Residential',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '5400 sq. ft.',
#   'Construction Completion': 2018,
#   'Floor area': 5400.0}}

# %%
with open("data/PHIUS.json", 'r') as f:
        known_projects = json.load(f)
with open("data/known_coords.json", 'r') as f:
        known_locs = json.load(f)

# %%
known_projects
# Out:
# {'Santaella Gardens': {'link': 'https://www.phius.org/certified-project-database/santaella-gardens',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '214543 sq. ft.',
#   'Construction Completion': '2019',
#   'Floor area': 214543.0,
#   'Phius Certified Verifier': 'Avery Gray',
#   'Phius CPHC (Lead)': 'Carmel Pratt',
#   'Project Submitter': 'Jordana Viuker',
#   'Construction Company': '1675 JV Associates LLC',
#   'Construction Type': 'Masonry',
#   'Number of Units': '249',
#   'Number of Stories': '11',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'March 29, 2019',
#   'Final Certification': 'March 25, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '2.11',
#   'Annual Cooling Demand': '5.18',
#   'Peak Heating Load': '3.36',
#   'Peak Cooling Load': '2.69',
#   'Site Energy Use Index (EUI)': '24.8',
#   'Site Energy Use Index (w/Renewables)': '21.82',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6327',
#   'Source Energy (Residential w/Renewables)': '5360',
#   'Air Tightness (per enclosure area)': '0.046',
#   'Average Compartmentalization': '0.19',
#   'Facade Type': 'Masonry Veneer',
#   'Wall 1 Type': 'Other',
#   'Wall 1 R-Value': '21',
#   'Wall 1 Insulation Type': 'Mineral Wool (Board)',
#   'Wall 2 Type': 'Exterior Continuous Insulation Only',
#   'Wall 2 R-Value': '24',
#   'Wall 2 Insulation Type': 'XPS',
#   'Roof 1 Type': 'Unvented Roof',
#   'Roof 1 R-Value': '50',
#   'Roof 1 Insulation Type': 'PolyIso',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '21',
#   'Floor 1 Insulation Type': 'XPS',
#   'Window Manufacturer 1': 'REHAU',
#   'Whole Window U-Value 1': '0.3',
#   'Window Glazing SHGC 1': '0.3',
#   'Window Manufacturer 2': 'REHAU',
#   'Whole Window U-Value 2': '0.3',
#   'Window Glazing SHGC 2': '0.27',
#   'Window Manufacturer 3': 'YKK',
#   'Window Product Name 3': 'YES 60 TU',
#   'Whole Window U-Value 3': '0.47',
#   'Window Glazing SHGC 3': '0.37',
#   'Ventilation System Manufacturer': 'Swegon',
#   'Ventilation System Product Name': 'Gold RX 07, 11, 14',
#   'Ventilation System Layout': 'Semi-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '82.4',
#   'Latent Recovery Efficiency': '0.74',
#   'Measured Ventilation Fan Efficiency': '1.5',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Variable Refrigerant Flow (VRF)',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Variable Refrigerant Flow (VRF)',
#   'Hot Water System Manufacturer': 'Intellihot',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Natural Gas Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '192321',
#   'Renewable Energy System Size': '162.7',
#   'location': 'Bronx, New York',
#   'Location': {'type': 'Point', 'coordinates': [-73.8785937, 40.8466508]}},
#  'Oak Tree Village - Building A': {'link': 'https://www.phius.org/certified-project-database/oak-tree-village-building',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45195 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 45195.0,
#   'Phius Certified Verifier': 'Nicole Burger',
#   'Project Submitter': 'Kai Fast',
#   'Construction Company': 'Dakota Partners',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '36',
#   'Number of Stories': '4',
#   'Program Version': 'PHIUS+ 2018 CORE',
#   'Design Certification': 'July 6, 2021',
#   'Final Certification': 'March 22, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '2.85',
#   'Annual Cooling Demand': '3.25',
#   'Peak Heating Load': '2.55',
#   'Peak Cooling Load': '1.87',
#   'Site Energy Use Index (EUI)': '18.08',
#   'Site Energy Use Index (w/Renewables)': '16.95',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5761',
#   'Source Energy (Residential w/Renewables)': '5336',
#   'Air Tightness (per enclosure area)': '0.0366',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '32',
#   'Wall 1 Insulation Type': 'PolyIso, Cellulose',
#   'Wall 2 Type': 'Exterior Continuous Insulation Only',
#   'Wall 2 R-Value': '13',
#   'Wall 2 Insulation Type': 'EPS',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '60',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Roof 2 Type': 'Unvented',
#   'Roof 2 R-Value': '43',
#   'Roof 2 Insulation Type': 'PolyIso',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '32',
#   'Floor 1 Insulation Type': 'EPS',
#   'Floor Type 2': 'Basement Slab',
#   'Floor 2 R-Value': '16',
#   'Floor 2 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Sanford Hills',
#   'Window Product Name 1': 'Fixed w/CG 70/36 + 70/36',
#   'Whole Window U-Value 1': '0.2',
#   'Window Glazing SHGC 1': '0.34',
#   'Window Manufacturer 2': 'Sanford Hills',
#   'Window Product Name 2': 'Casement w/ CG 70/36 + 70/36',
#   'Whole Window U-Value 2': '0.2',
#   'Window Glazing SHGC 2': '0.34',
#   'Window Manufacturer 3': 'Kawneer',
#   'Window Product Name 3': 'Trifab Storefront with Solarban60',
#   'Whole Window U-Value 3': '0.36',
#   'Window Glazing SHGC 3': '0.39',
#   'Whole Door U-Value': '0.15',
#   'Ventilation System Manufacturer': 'Mitsubishi',
#   'Ventilation System Product Name': 'LGH-F470RX',
#   'Ventilation System Layout': 'Semi-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '71',
#   'Latent Recovery Efficiency': '40',
#   'Measured Ventilation Fan Efficiency': '0.78',
#   'Heating System Manufacturer': 'Daikin',
#   'Heating System Product Name': 'RXYQ96TATJU',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Daikin',
#   'Cooling System Product Name': 'RXYQ96TATJU',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Rinnai',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Natural Gas Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '15000',
#   'Renewable Energy System Size': '11',
#   'location': 'Griswold, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-71.9622443, 41.6035026]}},
#  'Silvergreen': {'link': 'https://www.phius.org/certified-project-database/silvergreen',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '8456 sq. ft.',
#   'Construction Completion': '2019',
#   'Floor area': 8456.0,
#   'Phius Certified Verifier': 'Angela Iraldi',
#   'Phius CPHC (Secondary)': 'Joseph Holloway',
#   'Phius CPHC (Lead)': 'Tiffany Rolfing',
#   'Project Submitter': 'David Salamon',
#   'Construction Company': 'Custom Residential Construction / Hugh Lofting High Performance Homes',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '2',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018',
#   'All Electric': 'Yes',
#   'Design Certification': 'October 28, 2019',
#   'Final Certification': 'March 18, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.93',
#   'Annual Cooling Demand': '2.78',
#   'Peak Heating Load': '3.69',
#   'Peak Cooling Load': '1.57',
#   'Site Energy Use Index (EUI)': '9.57',
#   'Site Energy Use Index (w/Renewables)': '-0.52',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8300',
#   'Air Tightness (per enclosure area)': '0.056',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '37',
#   'Wall 1 Insulation Type': 'Fiberboard, Cellulose',
#   'Wall 2 Type': 'Insulated Concrete Form (ICF)',
#   'Wall 2 R-Value': '41',
#   'Wall 2 Insulation Type': 'EPS',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '79',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Roof 2 Type': 'Unvented',
#   'Roof 2 R-Value': '20',
#   'Roof 2 Insulation Type': 'EPS',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '24',
#   'Floor 1 Insulation Type': 'Mineral Wool',
#   'Window Manufacturer 1': 'Zola',
#   'Window Product Name 1': 'Thermoclad PLUS Tilt and Turn',
#   'Whole Window U-Value 1': '0.15',
#   'Window Glazing SHGC 1': '0.5',
#   'Window Manufacturer 2': 'Zola',
#   'Window Product Name 2': 'ThermoWood Fixed',
#   'Whole Window U-Value 2': '0.17',
#   'Window Frame Material 2': 'Wood',
#   'Window Glazing SHGC 2': '0.5',
#   'Window Manufacturer 3': 'Zola',
#   'Window Product Name 3': 'Thermowood Terrace Door',
#   'Whole Window U-Value 3': '0.17',
#   'Window Glazing SHGC 3': '0.5',
#   'Door Manufacturer': 'Zola',
#   'Door Product Name': 'ThermoWood Door',
#   'Whole Door U-Value': '0.17',
#   'Ventilation System Manufacturer': 'Zehnder',
#   'Ventilation System Product Name': 'ComfoAir Q600',
#   'Ventilation System Layout': 'De-Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '80',
#   'Latent Recovery Efficiency': '68',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Rheem',
#   'Hot Water System Product Name': 'PROPH65',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'Community Solar',
#   'Renewable Energy Annual Production': '25000',
#   'location': 'Bryn Athyn, Pennsylvania',
#   'Location': {'type': 'Point',
#    'coordinates': [-75.07212510775798, 40.14273955]}},
#  'Tenney Residence': {'link': 'https://www.phius.org/certified-project-database/tenney-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '3450 sq. ft.',
#   'Floor area': 3450.0,
#   'Phius CPHC (Secondary)': 'Thomas Candee',
#   'Phius Certified Rater': 'David Brach',
#   'Project Submitter': 'David Brach',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'February 21, 2022',
#   'Final Certification': 'March 4, 2022',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '5.91',
#   'Annual Cooling Demand': '1.8',
#   'Peak Heating Load': '3.45',
#   'Peak Cooling Load': '1.29',
#   'Site Energy Use Index (EUI)': '9.81',
#   'Site Energy Use Index (w/Renewables)': '-3.1',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5553',
#   'HERS Rating w/Renewables': '-6',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Wall 1 Type': 'Exterior Load Bearing Double-Stud',
#   'Wall 1 R-Value': '40',
#   'Wall 1 Insulation Type': 'Fiberglass',
#   'Wall 2 Type': 'Other',
#   'Wall 2 R-Value': '33',
#   'Wall 2 Insulation Type': 'EPS, Fiberglass',
#   'Roof 1 Type': 'Unvented Roof',
#   'Roof 1 R-Value': '61',
#   'Roof 1 Insulation Type': 'EPS, Fiberglass',
#   'Floor Type 1': 'Basement Slab',
#   'Floor 1 R-Value': '20',
#   'Floor 1 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Alpen',
#   'Window Product Name 1': 'Tyrol Series 9 Balanced Tilt Turn',
#   'Whole Window U-Value 1': '0.14',
#   'Window Glazing SHGC 1': '0.33',
#   'Window Manufacturer 2': 'Alpen',
#   'Window Product Name 2': 'Tyrol Series 9 Balanced Fixed',
#   'Whole Window U-Value 2': '0.14',
#   'Window Glazing SHGC 2': '0.33',
#   'Window Manufacturer 3': 'Alpen',
#   'Window Product Name 3': 'Alpen Tyrol Series 9 Balanced Swing Door "Standard"',
#   'Whole Window U-Value 3': '0.16',
#   'Window Glazing SHGC 3': '0.33',
#   'Ventilation System Manufacturer': 'UltimateAir',
#   'Ventilation System Product Name': 'RecoupAerator 200DX',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'HRV',
#   'Sensible Recovery Efficiency': '82',
#   'Measured Ventilation Fan Efficiency': '0.29',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Hot Water System Manufacturer': 'Stiebel Eltron',
#   'Hot Water System Product Name': 'Accelera 300E',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Range Hood Type': 'Recirculation',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '13048',
#   'Renewable Energy System Size': '9',
#   'location': 'Salt Lake City, Utah',
#   'Location': {'type': 'Point', 'coordinates': [-111.8867975, 40.7596198]}},
#  'Lam Residence': {'link': 'https://www.phius.org/certified-project-database/lam-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1473 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 1473.0,
#   'Phius Certified Rater': 'Michael Browne',
#   'Phius CPHC (Lead)': 'Jordan Goldman',
#   'Project Submitter': 'Jordan Goldman',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Adams + Beasley Associates',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 12, 2020',
#   'Final Certification': 'February 18, 2022',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '9.74',
#   'Annual Cooling Demand': '2.08',
#   'Peak Heating Load': '7.08',
#   'Peak Cooling Load': '2.99',
#   'Site Energy Use Index (EUI)': '16.11',
#   'Site Energy Use Index (w/Renewables)': '-3.83',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6489',
#   'HERS Rating': '26',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '34',
#   'Wall 1 Insulation Type': 'Fiberboard, Cellulose',
#   'Roof 1 Type': 'Vented Above Deck',
#   'Roof 1 R-Value': '63',
#   'Roof 1 Insulation Type': 'Cellulose',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '27',
#   'Floor 1 Insulation Type': 'EPS',
#   'Window Manufacturer 1': 'Schuco',
#   'Window Product Name 1': 'Living MD (Fixed)',
#   'Whole Window U-Value 1': '0.13',
#   'Window Glazing SHGC 1': '0.54',
#   'Window Manufacturer 2': 'Schuco',
#   'Window Product Name 2': 'Living MD (Operable)',
#   'Whole Window U-Value 2': '0.13',
#   'Window Glazing SHGC 2': '0.54',
#   'Window Manufacturer 3': 'Schuco',
#   'Window Product Name 3': 'Living Slide',
#   'Whole Window U-Value 3': '0.17',
#   'Window Glazing SHGC 3': '0.54',
#   'Whole Door U-Value': '0.17',
#   'Ventilation System Manufacturer': 'Zehnder',
#   'Ventilation System Product Name': 'Comfair Q350',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'ERV',
#   'Sensible Recovery Efficiency': '86',
#   'Latent Recovery Efficiency': '73',
#   'Measured Ventilation Fan Efficiency': '0.17',
#   'Heating System Manufacturer': 'Mitsubishi',
#   'Heating System Product Name': 'SUZ-KA18NAHZ',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Heating System Rating': 'COP',
#   'Heating System Performance (COP)': '3',
#   'Cooling System Manufacturer': 'Mitsubishi',
#   'Cooling System Product Name': 'SUZ-KA18NAHZ',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Cooling System Rating': 'EER',
#   'Cooling System Performance (EER)': '12.5',
#   'Hot Water System Manufacturer': 'Bradford',
#   'Hot Water System Product Name': 'Aerotherm 65 gallon',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Heat Pump Water Heater',
#   'Hot Water System Rating': 'Energy Factor (EF)',
#   'Hot Water System Performance Rating': '3.58',
#   'Range Hood Type': 'Exhaust',
#   'Dryer Type': 'Non-Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '8607',
#   'Renewable Energy System Size': '6.8',
#   'location': 'Acton, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.43284, 42.4850931]}},
#  'Theresa Passive House': {'link': 'https://www.phius.org/certified-project-database/theresa-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'Addition',
#   'ASHRAE Climate Zone': '2A - Hot - Humid',
#   'INT. Conditioned Floor Area': '2218 sq. ft.',
#   'Floor area': 2218.0,
#   'Phius CPHC (Lead)': 'Nick Calcagni',
#   'Project Submitter': 'Trey Farmer',
#   'Construction Company': 'CleanTag LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'April 6, 2021',
#   'Final Certification': 'February 4, 2022',
#   'Region': 'South Central',
#   'Annual Heating Demand': '2.9',
#   'Annual Cooling Demand': '12.07',
#   'Peak Heating Load': '5.58',
#   'Peak Cooling Load': '3.73',
#   'Site Energy Use Index (EUI)': '12.66',
#   'Site Energy Use Index (w/Renewables)': '-1.76',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6459',
#   'Air Tightness (per enclosure area)': '0.036',
#   'Measured Ventilation Fan Efficiency': '0.8',
#   'location': 'Austin, Texas',
#   'Location': {'type': 'Point', 'coordinates': [-97.7436995, 30.2711286]}},
#  'Sunset Residence': {'link': 'https://www.phius.org/certified-project-database/sunset-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1645 sq. ft.',
#   'Floor area': 1645.0,
#   'Phius CPHC (Secondary)': 'Bruce Friedman',
#   'Phius CPHC (Lead)': 'Karan Gupta',
#   'Project Submitter': 'Meghan Hanson',
#   'Building Owner': 'Michael Sylvester & Meghan Hanson',
#   'Construction Company': 'Hone Architects& Builders',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'October 22, 2020',
#   'Final Certification': 'January 12, 2022',
#   'Region': 'North Central',
#   'Annual Heating Demand': '12.15',
#   'Annual Cooling Demand': '6.15',
#   'Peak Heating Load': '8.58',
#   'Peak Cooling Load': '3.49',
#   'Site Energy Use Index (EUI)': '18.3',
#   'Site Energy Use Index (w/Renewables)': '-0.99',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8234',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Stevensville, Montana',
#   'Location': {'type': 'Point', 'coordinates': [-114.094385, 46.510407]}},
#  'Red Clay Creek': {'link': 'https://www.phius.org/certified-project-database/red-clay-creek',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '2898 sq. ft.',
#   'Floor area': 2898.0,
#   'Phius Certified Rater': 'David Berg',
#   'Phius CPHC (Secondary)': 'Kelly Fordice',
#   'Phius CPHC (Lead)': 'Paula Loomis',
#   'Project Submitter': 'Ilka Cassidy',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Hugh Lofting High Performance Building/ Holzraum System LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 6, 2019',
#   'Final Certification': 'December 23, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '6.16',
#   'Annual Cooling Demand': '2.36',
#   'Peak Heating Load': '4.43',
#   'Peak Cooling Load': '1.81',
#   'Site Energy Use Index (EUI)': '10.64',
#   'Site Energy Use Index (w/Renewables)': '-3.2',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6327',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.4',
#   'location': 'Kennett Square, Pennsylvania',
#   'Location': {'type': 'Point', 'coordinates': [-75.7116997, 39.8467414]}},
#  'Pipsqueak': {'link': 'https://www.phius.org/certified-project-database/pipsqueak',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5B - Cool - Dry',
#   'INT. Conditioned Floor Area': '1738 sq. ft.',
#   'Floor area': 1738.0,
#   'Phius CPHC (Lead)': 'Eric Davenport',
#   'Project Submitter': 'Thomas Candee',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Domain LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'September 27, 2019',
#   'Final Certification': 'December 23, 2021',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '4.96',
#   'Annual Cooling Demand': '2.78',
#   'Peak Heating Load': '3.88',
#   'Peak Cooling Load': '2.77',
#   'Site Energy Use Index (EUI)': '13.12',
#   'Site Energy Use Index (w/Renewables)': '8.54',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5279',
#   'Source Energy (Residential w/Renewables)': '3389',
#   'Air Tightness (per enclosure area)': '0.032',
#   'Measured Ventilation Fan Efficiency': '1',
#   'location': 'Salt Lake City, Utah',
#   'Location': {'type': 'Point', 'coordinates': [-111.8867975, 40.7596198]}},
#  '11 Crown Street - Colony Street Townhomes': {'link': 'https://www.phius.org/certified-project-database/11-crown-street-colony-street-townhomes',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '12288 sq. ft.',
#   'Floor area': 12288.0,
#   'Phius Certified Verifier': 'Karla Butterfield',
#   'Phius CPHC (Lead)': 'Samina Iqbal',
#   'Project Submitter': 'Thomas Moore',
#   'Secondary Reviewer': 'Lisa White',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'The Michaels Organization',
#   'Number of Units': '8',
#   'Number of Stories': '3',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'August 27, 2018',
#   'Final Certification': 'November 23, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '4.72',
#   'Annual Cooling Demand': '0.7',
#   'Peak Heating Load': '3.85',
#   'Peak Cooling Load': '1.8',
#   'Site Energy Use Index (EUI)': '16.01',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '4715',
#   'Air Tightness (per enclosure area)': '0.064',
#   'Measured Ventilation Fan Efficiency': '0.4',
#   'location': 'Meriden, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.8070435, 41.5381535]}},
#  'Westbrook Village Phase 2 - Building 12': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-12',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '9946 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 9946.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 15, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.35',
#   'Annual Cooling Demand': '1.93',
#   'Peak Heating Load': '4.02',
#   'Peak Cooling Load': '2.72',
#   'Site Energy Use Index (EUI)': '20.65',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '4900',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Measured Ventilation Fan Efficiency': '0.2',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Westbrook Village Phase 2 - Building 11': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-11',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10704 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 10704.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 15, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.47',
#   'Annual Cooling Demand': '2.32',
#   'Peak Heating Load': '4.16',
#   'Peak Cooling Load': '2.98',
#   'Site Energy Use Index (EUI)': '21.72',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5705',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Westbrook Village Phase 2 - Building 10': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-10',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '13748 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 13748.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '12',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '4.29',
#   'Annual Cooling Demand': '1.75',
#   'Peak Heating Load': '3.59',
#   'Peak Cooling Load': '2.44',
#   'Site Energy Use Index (EUI)': '19.3',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5361',
#   'Air Tightness (per enclosure area)': '0.047',
#   'Measured Ventilation Fan Efficiency': '0.6',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Westbrook Village Phase 2 - Building 09': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-09',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '6836 sq. ft.',
#   'Floor area': 6836.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.38',
#   'Annual Cooling Demand': '1.93',
#   'Peak Heating Load': '4.18',
#   'Peak Cooling Load': '2.73',
#   'Site Energy Use Index (EUI)': '20.28',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5576',
#   'Air Tightness (per enclosure area)': '0.043',
#   'Measured Ventilation Fan Efficiency': '0.5',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Westbrook Village Phase 2 - Building 08': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-08',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '10378 sq. ft.',
#   'Floor area': 10378.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '12',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.08',
#   'Annual Cooling Demand': '1.09',
#   'Peak Heating Load': '3.74',
#   'Peak Cooling Load': '1.83',
#   'Site Energy Use Index (EUI)': '18.84',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6164',
#   'Air Tightness (per enclosure area)': '0.042',
#   'Measured Ventilation Fan Efficiency': '0.5',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Westbrook Village Phase 2 - Building 07': {'link': 'https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-07',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '8647 sq. ft.',
#   'Floor area': 8647.0,
#   'Phius Certified Verifier': 'Vaughan Piccolo',
#   'Phius CPHC (Lead)': 'Sangeetha Sambandam',
#   'Project Submitter': 'Sangeetha Sambandam',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Westbrook II Housing LLC',
#   'Construction Company': 'Haynes Construction Company',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '10',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 12, 2021',
#   'Final Certification': 'November 19, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '5.16',
#   'Annual Cooling Demand': '1.44',
#   'Peak Heating Load': '3.92',
#   'Peak Cooling Load': '2.21',
#   'Site Energy Use Index (EUI)': '19.6',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6464',
#   'Air Tightness (per enclosure area)': '0.05',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'location': 'Hartford, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.6908547, 41.764582]}},
#  'Maple Corner Passive House': {'link': 'https://www.phius.org/certified-project-database/maple-corner-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1288 sq. ft.',
#   'Floor area': 1288.0,
#   'Phius Certified Rater': 'Karen Bushey',
#   'Phius CPHC (Secondary)': 'Matt Fletcher',
#   'Phius CPHC (Lead)': 'Allen Brown',
#   'Project Submitter': 'Christopher Clarke Miksic',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Building Owner': 'Meg and John Dawkins',
#   'Construction Company': 'Montpelier Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'November 27, 2019',
#   'Final Certification': 'November 1, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '9.4',
#   'Annual Cooling Demand': '1.37',
#   'Peak Heating Load': '5.99',
#   'Peak Cooling Load': '2.4',
#   'Site Energy Use Index (EUI)': '15.61',
#   'Site Energy Use Index (w/Renewables)': '-5.09',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5498',
#   'Air Tightness (per enclosure area)': '0.028',
#   'Measured Ventilation Fan Efficiency': '0.7',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Calais, Vermont',
#   'Location': {'type': 'Point', 'coordinates': [-72.4681875, 44.3692263]}},
#  'Hom Hanan House': {'link': 'https://www.phius.org/certified-project-database/hom-hanan-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '1819 sq. ft.',
#   'Floor area': 1819.0,
#   'Phius CPHC (Lead)': 'Douglas Rand',
#   'Project Submitter': 'Edwin May',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Joe Hom & Daniel Hanan',
#   'Construction Company': 'Cross Builders',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'January 4, 2021',
#   'Final Certification': 'October 8, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '7.09',
#   'Annual Cooling Demand': '2.88',
#   'Peak Heating Load': '5.12',
#   'Peak Cooling Load': '2.61',
#   'Site Energy Use Index (EUI)': '11.95',
#   'Site Energy Use Index (w/Renewables)': '4.56',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '5947',
#   'Source Energy (Residential w/Renewables)': '2271',
#   'Air Tightness (per enclosure area)': '0.037',
#   'Measured Ventilation Fan Efficiency': '0.4',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Long Branch, New Jersey',
#   'Location': {'type': 'Point', 'coordinates': [-73.9923596, 40.3042778]}},
#  'Anthony Wayne III': {'link': 'https://www.phius.org/certified-project-database/anthony-wayne-iii',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '39806 sq. ft.',
#   'Construction Completion': '2017',
#   'Floor area': 39806.0,
#   'Phius Certified Rater': 'Brian Stanfill',
#   'Phius CPHC (Lead)': 'John Semmelhack',
#   'Project Submitter': 'John Semmelhack',
#   'Building Owner': 'Elon Development Company',
#   'Number of Units': '45',
#   'Number of Stories': '3',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'May 16, 2017',
#   'Final Certification': 'October 6, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '3.33',
#   'Annual Cooling Demand': '5.19',
#   'Peak Heating Load': '3.18',
#   'Peak Cooling Load': '2.65',
#   'Site Energy Use Index (EUI)': '21.69',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6214',
#   'Air Tightness (per enclosure area)': '0.048',
#   'Measured Ventilation Fan Efficiency': '0.6',
#   'location': 'Philadelphia, Pennsylvania',
#   'Location': {'type': 'Point', 'coordinates': [-75.1635262, 39.9527237]}},
#  '1300 Pike': {'link': 'https://www.phius.org/certified-project-database/1300-pike',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '29490 sq. ft.',
#   'Construction Completion': '2016',
#   'Floor area': 29490.0,
#   'Phius Certified Verifier': 'Greta Tjeltveit',
#   'Phius Certified Rater': 'Greta Tjeltveit',
#   'Phius CPHC (Lead)': 'Paul Knight',
#   'Project Submitter': 'Daniel Luddy',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Solis Seattle, LLC',
#   'Construction Company': 'Cascade Built',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '45',
#   'Number of Stories': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'November 6, 2019',
#   'Final Certification': 'September 27, 2021',
#   'Region': 'Northwest',
#   'Annual Heating Demand': '3.03',
#   'Annual Cooling Demand': '1',
#   'Peak Heating Load': '3.47',
#   'Peak Cooling Load': '1.81',
#   'Site Energy Use Index (EUI)': '27.59',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6075',
#   'Air Tightness (per enclosure area)': '0.05',
#   'Measured Ventilation Fan Efficiency': '1.5',
#   'location': 'Seattle, Washington',
#   'Location': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#  'Fortin Residence': {'link': 'https://www.phius.org/certified-project-database/fortin-residence',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '1019 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 1019.0,
#   'Phius CPHC (Lead)': 'Junko Iwasaki',
#   'Project Submitter': 'James Mustillo',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Company': 'GO Logic LLC',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'February 2, 2021',
#   'Final Certification': 'September 13, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '10.22',
#   'Annual Cooling Demand': '2.19',
#   'Peak Heating Load': '7.7',
#   'Peak Cooling Load': '2.49',
#   'Site Energy Use Index (EUI)': '22.54',
#   'Site Energy Use Index (w/Renewables)': '6.44',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6284',
#   'Source Energy (Residential w/Renewables)': '1796',
#   'Air Tightness (per enclosure area)': '0.033',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Denmark, Maine',
#   'Location': {'type': 'Point', 'coordinates': [-70.803452, 43.970581]}},
#  'Northbrook Park District Activity Center': {'link': 'https://www.phius.org/certified-project-database/northbrook-park-district-activity-center',
#   'Status': 'Final Certified',
#   'Building Function': 'Government / Public',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44048 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 44048.0,
#   'Phius Certified Verifier': 'Lindsey Elton',
#   'Phius CPHC (Secondary)': 'Daniel Razzano',
#   'Phius CPHC (Lead)': 'Zhongdi Chen',
#   'Project Submitter': 'Zhongdi Chen',
#   'Secondary Reviewer': 'Lisa White',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Type': 'Insulated Concrete Form (ICF)',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015 Source Zero',
#   "ADD'L Certification Badges": 'PHIUS+ Source Zero',
#   'Design Certification': 'June 14, 2019',
#   'Final Certification': 'August 20, 2021',
#   'Region': 'Midwest',
#   'Annual Heating Demand': '3.9',
#   'Annual Cooling Demand': '3.36',
#   'Peak Heating Load': '4.85',
#   'Peak Cooling Load': '2.91',
#   'Site Energy Use Index (EUI)': '27.79',
#   'Site Energy Use Index (w/Renewables)': '22.16',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Non-Residential)': '71.92',
#   'Source Energy (Non-Residential w/Renewables)': '52.72',
#   'Air Tightness (per enclosure area)': '0.049',
#   'Measured Ventilation Fan Efficiency': '1.2',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Northbrook, Illinois',
#   'Location': {'type': 'Point', 'coordinates': [-87.8265089, 42.128704]}},
#  'Sonoran Desert Passive': {'link': 'https://www.phius.org/certified-project-database/sonoran-desert-passive',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '2B - Hot - Dry',
#   'INT. Conditioned Floor Area': '2925 sq. ft.',
#   'Floor area': 2925.0,
#   'Phius Certified Rater': 'Michael Bestenlehner',
#   'Phius CPHC (Secondary)': 'Audrey Godwin',
#   'Phius CPHC (Lead)': 'Audrey Godwin',
#   'Project Submitter': 'David Brubaker',
#   'Primary Reviewer': 'Lisa White',
#   'Building Owner': 'David Brubaker',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2015',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'December 12, 2016',
#   'Final Certification': 'August 20, 2021',
#   'Region': 'Southwest',
#   'Annual Heating Demand': '0.23',
#   'Annual Cooling Demand': '8.5',
#   'Peak Heating Load': '1.61',
#   'Peak Cooling Load': '3.32',
#   'Site Energy Use Index (EUI)': '12.02',
#   'Site Energy Use Index (w/Renewables)': '7.36',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '8139',
#   'Source Energy (Residential w/Renewables)': '5200',
#   'Air Tightness (per enclosure area)': '0.027',
#   'Measured Ventilation Fan Efficiency': '0.3',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'location': 'Tucson, Arizona',
#   'Location': {'type': 'Point', 'coordinates': [-110.9748477, 32.2228765]}},
#  'Bowdoin College SCSC - LLC': {'link': 'https://www.phius.org/certified-project-database/bowdoin-college-scsc-llc',
#   'Status': 'Final Certified',
#   'Building Function': 'School / Education',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '5373 sq. ft.',
#   'Floor area': 5373.0,
#   'Phius Certified Verifier': 'Gert Guldentops',
#   'Phius CPHC (Lead)': 'Oliver Baumann',
#   'Project Submitter': 'Elsa Mullin',
#   'Primary Reviewer': 'James Ortega',
#   'Building Owner': 'Bowdoin College',
#   'Construction Company': 'JF Scott Construction (Adam Lyons)',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   'Design Certification': 'November 6, 2020',
#   'Final Certification': 'August 4, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '10.5',
#   'Annual Cooling Demand': '2.33',
#   'Peak Heating Load': '7.66',
#   'Peak Cooling Load': '1.89',
#   'Site Energy Use Index (EUI)': '23.57',
#   'Site Energy Use Index (w/Renewables)': '14.62',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Non-Residential)': '59.07',
#   'Source Energy (Non-Residential w/Renewables)': '34',
#   'Air Tightness (per enclosure area)': '0.073',
#   'Measured Ventilation Fan Efficiency': '1.5',
#   'Renewable Energy Type(s)': 'RECs (Renewable Energy Certificates)',
#   'location': "Orr's Island, Maine",
#   'Location': {'type': 'Point',
#    'coordinates': [-69.96497497313277, 43.77249795]}},
#  'Rose Lane Passive House': {'link': 'https://www.phius.org/certified-project-database/rose-lane-passive-house',
#   'Status': 'Final Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4C - Mixed - Marine',
#   'INT. Conditioned Floor Area': '1730 sq. ft.',
#   'Floor area': 1730.0,
#   'Phius Certified Rater': 'Marc Cregeur',
#   'Phius CPHC (Secondary)': 'Alison Kwok',
#   'Phius CPHC (Lead)': 'Jeffrey Pelletier',
#   'Project Submitter': 'Jonathan Bean',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Building Owner': 'Alison Kwok',
#   'Construction Company': 'Paul Allen, Allen Co Design It! Build it!',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Number of Stories': '2',
#   'Program Version': 'PHIUS+ 2018',
#   'All Electric': 'Yes',
#   "ADD'L Certifications": 'DOE ZERH, ENERGY STAR for Homes, EPA Indoor airPLUS',
#   'Design Certification': 'October 7, 2020',
#   'Final Certification': 'August 4, 2021',
#   'Region': 'Northwest',
#   'Annual Heating Demand': '5.69',
#   'Annual Cooling Demand': '2.65',
#   'Peak Heating Load': '3.75',
#   'Peak Cooling Load': '3.25',
#   'Site Energy Use Index (EUI)': '21.23',
#   'Site Energy Use Index (w/Renewables)': '15.13',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '7535',
#   'Source Energy (Residential w/Renewables)': '5371',
#   'Air Tightness (per enclosure area)': '0.057',
#   'Facade Type': 'Fiber Cement',
#   'Wall 1 Type': 'Framing with Continuous Insulation',
#   'Wall 1 R-Value': '25',
#   'Wall 1 Insulation Type': 'Fiberglass, Mineral Wool',
#   'Wall 2 Type': 'Other',
#   'Wall 2 R-Value': '25',
#   'Wall 2 Insulation Type': 'XPS, Fiberglass',
#   'Roof 1 Type': 'Vented Below Deck',
#   'Roof 1 R-Value': '104',
#   'Roof 1 Insulation Type': 'Fiberglass',
#   'Floor Type 1': 'Slab on Grade',
#   'Floor 1 R-Value': '25',
#   'Floor 1 Insulation Type': 'EPS',
#   'Floor Type 2': 'Overhang Floor',
#   'Floor 2 R-Value': '55',
#   'Floor 2 Insulation Type': 'Fiberglass',
#   'Window Manufacturer 1': 'Zola',
#   'Window Product Name 1': 'Thermo uPVC',
#   'Whole Window U-Value 1': '0.16',
#   'Window Frame Material 1': 'Unplasticized Polyvinyl Chloride (uPVC)',
#   'Window Glazing SHGC 1': '0.5',
#   'Ventilation System Manufacturer': 'Minotair',
#   'Ventilation System Product Name': 'PentaCare V12',
#   'Ventilation System Layout': 'Centralized',
#   'Ventilation System Type': 'Multifunction',
#   'Sensible Recovery Efficiency': '100',
#   'Measured Ventilation Fan Efficiency': '1',
#   'Heating System Manufacturer': 'Minotair',
#   'Heating System Product Name': 'PentaCare V12',
#   'Heating System Type': 'Air Source Heat Pump',
#   'Heating System Rating': 'COP',
#   'Heating System Performance (COP)': '3',
#   'Cooling System Manufacturer': 'Minotair',
#   'Cooling System Product Name': 'PentaCare V12',
#   'Cooling System Type': 'Air Source Heat Pump',
#   'Cooling System Rating': 'EER',
#   'Cooling System Performance Rating': '11.4',
#   'Hot Water System Manufacturer': 'Bradford White',
#   'Hot Water System Product Name': 'Upright 50 gal',
#   'Hot Water System Layout': 'Centralized',
#   'Hot Water System Type': 'Electric Water Heater',
#   'Hot Water System Rating': 'Uniform Energy Factor (UEF)',
#   'Hot Water System Performance Rating': '0.92',
#   'Range Hood Type': 'Exhaust',
#   'Dryer Type': 'Vented',
#   'Renewable Energy Type(s)': 'On-Site PV',
#   'Renewable Energy Annual Production': '3091',
#   'Renewable Energy System Size': '3.9',
#   'location': 'Eugene, Oregon',
#   'Location': {'type': 'Point', 'coordinates': [-123.0950506, 44.0505054]}},
#  'Mapes Apartments': {'link': 'https://www.phius.org/certified-project-database/mapes-apartments',
#   'Status': 'Final Certified',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '4A - Mixed - Humid',
#   'INT. Conditioned Floor Area': '29879 sq. ft.',
#   'Floor area': 29879.0,
#   'Phius CPHC (Lead)': 'Rebekah Shoup',
#   'Project Submitter': 'David Berger',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Type': 'Masonry',
#   'Number of Units': '30',
#   'Number of Stories': '6',
#   'Program Version': 'PHIUS+ 2015',
#   'Design Certification': 'July 1, 2019',
#   'Final Certification': 'July 8, 2021',
#   'Region': 'Northeast',
#   'Annual Heating Demand': '3.31',
#   'Annual Cooling Demand': '4.87',
#   'Peak Heating Load': '3.85',
#   'Peak Cooling Load': '2.42',
#   'Site Energy Use Index (EUI)': '27.69',
#   'Site Energy Use Index (w/Renewables)': '24.14',
#   'Compliance Software': 'WUFI Passive',
#   'Source Energy (Residential)': '6510',
#   'Source Energy (Residential w/Renewables)': '5379',
#   'Air Tightness (per enclosure area)': '0.11',
#   'Measured Ventilation Fan Efficiency': '1.1',
#   'location': 'Bronx, New York',
# ...
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '6225 sq. ft.',
#   'Floor area': 6225.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Ryan Abendroth',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  'MLK / Tyler Street Building 4': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-4',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '4800 sq. ft.',
#   'Floor area': 4800.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  'MLK / Tyler Street Building 3': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-3',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '5550 sq. ft.',
#   'Floor area': 5550.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  'MLK / Tyler Street Building 2': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-2',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  'MLK / Tyler Street Building 1': {'link': 'https://www.phius.org/certified-project-database/mlk-tyler-street-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'INT. Conditioned Floor Area': '7470 sq. ft.',
#   'Floor area': 7470.0,
#   'Phius CPHC (Lead)': 'Nicole Burger',
#   'Project Submitter': 'Nicole Burger',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  '340 Dixwell Building Two': {'link': 'https://www.phius.org/certified-project-database/340-dixwell-building-two',
#   'Status': 'Registered',
#   'Phius CPHC (Lead)': 'Paul Selnau',
#   'Project Submitter': 'Paul Selnau',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'New Haven, Connecticut',
#   'Location': {'type': 'Point', 'coordinates': [-72.9250518, 41.3082138]}},
#  'Environmental Charter School - High School': {'link': 'https://www.phius.org/certified-project-database/environmental-charter-school-high-school',
#   'Status': 'Registered',
#   'Phius CPHC (Lead)': 'Craig Stevenson',
#   'Project Submitter': 'Craig Stevenson',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Pittsburgh, Pennsylvania',
#   'Location': {'type': 'Point', 'coordinates': [-79.9900861, 40.4416941]}},
#  'Vaughan Residence': {'link': 'https://www.phius.org/certified-project-database/vaughan-residence',
#   'Status': 'Registered',
#   'Construction Completion': '2022',
#   'Phius CPHC (Lead)': 'Peter Schmelzer',
#   'Project Submitter': 'Peter Schmelzer',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Program Version': 'Phius CORE 2021',
#   'Compliance Software': 'WUFI Passive'},
#  'Residences on the Charles': {'link': 'https://www.phius.org/certified-project-database/residences-charles',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '45155 sq. ft.',
#   'Floor area': 45155.0,
#   'Phius CPHC (Lead)': 'Thomas Secondo',
#   'Project Submitter': 'Thomas Secondo',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Callahan Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '38',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.06',
#   'location': 'Newton, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.2092214, 42.3370414]}},
#  'Montecito Casa Pasiva': {'link': 'https://www.phius.org/certified-project-database/montecito-casa-pasiva',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '3C - Warm - Marine',
#   'INT. Conditioned Floor Area': '4482 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 4482.0,
#   'Phius CPHC (Lead)': 'Ilka Cassidy',
#   'Project Submitter': 'Ilka Cassidy',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Southwest',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Santa Barbara, California',
#   'Location': {'type': 'Point', 'coordinates': [-119.7026673, 34.4221319]}},
#  'West Side Homes Sustainable Rehabilitation & Infill Housing - Rhode Island': {'link': 'https://www.phius.org/certified-project-database/west-side-homes-sustainable-rehabilitation-infill-housing-rhode-island',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '4614 sq. ft.',
#   'Floor area': 4614.0,
#   'Phius CPHC (Lead)': 'Michelle Tinner',
#   'Project Submitter': 'Michelle Tinner',
#   'Primary Reviewer': 'Isaac Elnecave',
#   'Construction Company': 'PUSH Buffalo',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Buffalo, New York',
#   'Location': {'type': 'Point', 'coordinates': [-78.8783922, 42.8867166]}},
#  'Brewster Woods Community Housing - Building 40': {'link': 'https://www.phius.org/certified-project-database/brewster-woods-community-housing-building-40',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '28296 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 28296.0,
#   'Phius CPHC (Lead)': 'Ken Neuhauser',
#   'Project Submitter': 'Ken Neuhauser',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Delphi Construction, Inc.',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '23',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Brewster, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-70.082796, 41.7601093]}},
#  'JP Federal - Building 5': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-5',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '73313 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 73313.0,
#   'Phius CPHC (Lead)': 'Maciej Konieczny',
#   'Project Submitter': 'Maciej Konieczny',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'Consigli',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '40',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Cambridge, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.1056157, 42.3750997]}},
#  'JP Federal - Building 1': {'link': 'https://www.phius.org/certified-project-database/jp-federal-building-1',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '57899 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 57899.0,
#   'Phius CPHC (Lead)': 'Maciej Konieczny',
#   'Project Submitter': 'Maciej Konieczny',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Construction Company': 'Consigli',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '33',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Cambridge, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.1056157, 42.3750997]}},
#  'Bunker Hill Housing - Phase 1 (Building M)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-m',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '106660 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 106660.0,
#   'Phius CPHC (Lead)': 'Daniel Perez',
#   'Project Submitter': 'Daniel Perez',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Alexander Mitchell',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Boston, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.0582912, 42.3602534]}},
#  'Bunker Hill Housing - Phase 1 (Building F)': {'link': 'https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-f',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '234654 sq. ft.',
#   'Construction Completion': '2022',
#   'Floor area': 234654.0,
#   'Phius CPHC (Lead)': 'Daniel Perez',
#   'Project Submitter': 'Daniel Perez',
#   'Secondary Reviewer': 'James Ortega',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Boston, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-71.0582912, 42.3602534]}},
#  '337 Cumberland': {'link': 'https://www.phius.org/certified-project-database/337-cumberland',
#   'Status': 'Registered',
#   'Building Function': 'Mixed-Use',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '55270 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 55270.0,
#   'Project Submitter': 'Kai Fast',
#   'Construction Company': 'Ledgewood Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '96',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.06',
#   'location': 'Portland, Maine',
#   'Location': {'type': 'Point', 'coordinates': [-70.2548596, 43.6610277]}},
#  'McElwain Apartments': {'link': 'https://www.phius.org/certified-project-database/mcelwain-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '44189 sq. ft.',
#   'Floor area': 44189.0,
#   'Phius CPHC (Lead)': 'Ashley Wisse',
#   'Project Submitter': 'Ashley Wisse',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'CC MPZ Main Street LLC',
#   'Construction Type': 'Wood Frame',
#   'Program Version': 'PHIUS+ 2018',
#   'Region': 'Northeast',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Bridgewater, Massachusetts',
#   'Location': {'type': 'Point', 'coordinates': [-70.9750426, 41.9903787]}},
#  'Conservatory Apartments': {'link': 'https://www.phius.org/certified-project-database/conservatory-apartments',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '5A - Cool - Humid',
#   'INT. Conditioned Floor Area': '22848 sq. ft.',
#   'Construction Completion': '2021',
#   'Floor area': 22848.0,
#   'Phius CPHC (Lead)': 'Victor Rivera',
#   'Project Submitter': 'Victor Rivera',
#   'Primary Reviewer': 'Andres Pinzon',
#   'Construction Company': 'McShane Construction',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '44',
#   'Program Version': 'Phius CORE 2021',
#   'Region': 'Midwest',
#   'Compliance Software': 'WUFI Passive',
#   'Air Tightness (per enclosure area)': '0.05',
#   'location': 'Chicago, Illinois',
#   'Location': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]}},
#  'West Don Ravine Home': {'link': 'https://www.phius.org/certified-project-database/west-don-ravine-home',
#   'Status': 'Design Certified',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '3737 sq. ft.',
#   'Construction Completion': '2020',
#   'Floor area': 3737.0,
#   'Phius Certified Rater': 'Greg Leskien',
#   'Phius CPHC (Lead)': 'Jordan MacDonald',
#   'Project Submitter': 'Stuart Fix',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2018',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Toronto, Ontario',
#   'Location': {'type': 'Point', 'coordinates': [-93.6737694, 42.0359038]}},
#  '811 Gladstone': {'link': 'https://www.phius.org/certified-project-database/811-gladstone',
#   'Status': 'Registered',
#   'Building Function': 'Multifamily',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6A - Cool - Humid',
#   'INT. Conditioned Floor Area': '90828 sq. ft.',
#   'Floor area': 90828.0,
#   'Phius CPHC (Lead)': 'Taylor Schaefer',
#   'Project Submitter': 'Taylor Schaefer',
#   'Construction Type': 'Wood Frame',
#   'Program Version': 'PHIUS+ 2018',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'Ottawa, Ontario',
#   'Location': {'type': 'Point', 'coordinates': [-94.7630041, 36.9875663]}},
#  'Fairplay': {'link': 'https://www.phius.org/certified-project-database/fairplay',
#   'Status': 'Registered',
#   'Building Function': 'Single-Family',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '7B - Very Cold - Humid',
#   'INT. Conditioned Floor Area': '1155 sq. ft.',
#   'Floor area': 1155.0,
#   'Project Submitter': 'Brian Fuentes',
#   'Construction Company': 'TBD',
#   'Construction Type': 'Wood Frame',
#   'Number of Units': '1',
#   'Program Version': 'PHIUS+ 2012',
#   'Region': 'North Central',
#   'Compliance Software': 'PHPP',
#   'Heating System Type': 'Electric Resistance',
#   'location': 'Fairplay, Colorado',
#   'Location': {'type': 'Point',
#    'coordinates': [-105.99959752584583, 39.225224499999996]}},
#  'West Moberly Health Centre': {'link': 'https://www.phius.org/certified-project-database/west-moberly-health-centre',
#   'Status': 'Design Certified',
#   'Building Function': 'Other Non-Residential',
#   'Project Type': 'New Construction',
#   'ASHRAE Climate Zone': '6B - Cool - Dry',
#   'INT. Conditioned Floor Area': '5400 sq. ft.',
#   'Construction Completion': '2018',
#   'Floor area': 5400.0,
#   'Project Submitter': 'Brittany Coughlin',
#   'Construction Type': 'Wood Frame',
#   'Program Version': 'PHIUS+ 2015',
#   'Compliance Software': 'WUFI Passive',
#   'location': 'West Moberly, British Columbia',
#   'Location': {'type': 'Point', 'coordinates': [-121.5445822, 55.0947165]}}}

# %%
known_projects['Silvergreen']['Location']
# Out:
# {'type': 'Point', 'coordinates': [-75.07212510775798, 40.14273955]}

# %%
def point2multipoint(loc):
    if loc['type'] == 'Point':
        loc['type'] = 'MultiPoint'
        loc['coordinates'] = [loc['coordinates']]
    return loc

# %%
import datetime
import re

datematch = re.compile(r"(?P<month>[a-zA-Z]*) (?P<day>\d{1,2}), (?P<year>\d{4})")

# %%
monthnames = ['January', 'February', 'March', 'April', 'May', 'June', 
              'July', 'August', 'September', 'October', 'November', 'December']

# %%
def parse_date(v):
    if 'Final Certification' in v:
        m = datematch.match(v['Final Certification'])
        return datetime.datetime(year=int(m['year']), day=int(m['day']), 
                                 month=monthnames.index(m['month']) + 1).isoformat()
    else:
        return (datetime.datetime.now() + datetime.timedelta(days=356)).isoformat()

# %%
import folium
import folium.plugins

# %%
statuscolor = {'Pre-certified': "#C4F09E", 'Design Certified': "#C4F09E",
               'Certified': "#79BD9A", 'Final Certified': '#79BD9A',
                'Registered': "#FFFFFF", None: "#FFFFFF"}

out = {'type': "FeatureCollection", 'features': []}
for k, v in known_projects.items():
        if not 'Location' in v:
            print(f'Skipping {k} - unknown location')
            continue
        prop = {}
        status = v.get('Status', None)
        prop["marker-color"] = statuscolor[status]

        if v.get('Floor area', 0) > 10000:
            prop["marker-size"] = "large"
        else:
            prop["marker-symbol"] = "building"

        link = v['link']
        prop['name'] = f"<a href='{link}'>{k}</a>"
        desc = '<table>'
        desc = desc + '<tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr>'

        for col in ['Project Type', 'Building Function', 'Construction Type', 'INT. Conditioned Floor Area']:
            if col in v:
                desc = desc + f'<tr><td><strong>{col}</strong></td><td>{v[col]}</td></tr>'
        desc = desc + '</table>'
        prop['description'] = desc
        prop['times'] = [parse_date(v)]

        out['features'].append({"type": "Feature",
                                "geometry": point2multipoint(v['Location']),
                                "properties": prop})
# Out:
# Skipping Heritage Point - unknown location
# Skipping test project - unknown location
# Skipping Far View PH Residence - unknown location
# Skipping Robles Residence - unknown location
# Skipping Norman home addition - unknown location
# Skipping OPRC 7 Van Buren - unknown location
# Skipping 3 Van Horne - unknown location
# Skipping Wharton-Kelleher Residence - unknown location
# Skipping Harvey West Studios - unknown location
# Skipping Brooks Residence - unknown location
# Skipping Russell Home - unknown location
# Skipping Bronzeville Estates - Bronzeville House - unknown location
# Skipping Bronzeville Estates - 6th St Duplex(2) - unknown location
# Skipping Bronzeville Estates - 6th St Duplex(1) - unknown location
# Skipping Bronzeville Estates - 5th St Duplex(2) - unknown location
# Skipping Bronzeville Estates - 5th St Duplex(1) - unknown location
# Skipping Pan American Square - unknown location
# Skipping ZBrains Project - unknown location
# Skipping Vaughan Residence - unknown location

# %%
out
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-73.8785937, 40.8466508]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/santaella-gardens'>Santaella Gardens</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Masonry</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>214543 sq. ft.</td></tr></table>',
#     'times': ['2022-03-25T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.9622443, 41.6035026]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/oak-tree-village-building'>Oak Tree Village - Building A</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>45195 sq. ft.</td></tr></table>',
#     'times': ['2022-03-22T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-75.07212510775798, 40.14273955]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/silvergreen'>Silvergreen</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>8456 sq. ft.</td></tr></table>',
#     'times': ['2022-03-18T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-111.8867975, 40.7596198]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/tenney-residence'>Tenney Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3450 sq. ft.</td></tr></table>',
#     'times': ['2022-03-04T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.43284, 42.4850931]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/lam-residence'>Lam Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1473 sq. ft.</td></tr></table>',
#     'times': ['2022-02-18T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-97.7436995, 30.2711286]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/theresa-passive-house'>Theresa Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>Addition</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2218 sq. ft.</td></tr></table>',
#     'times': ['2022-02-04T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-114.094385, 46.510407]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/sunset-residence'>Sunset Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1645 sq. ft.</td></tr></table>',
#     'times': ['2022-01-12T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-75.7116997, 39.8467414]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/red-clay-creek'>Red Clay Creek</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2898 sq. ft.</td></tr></table>',
#     'times': ['2021-12-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-111.8867975, 40.7596198]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/pipsqueak'>Pipsqueak</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1738 sq. ft.</td></tr></table>',
#     'times': ['2021-12-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.8070435, 41.5381535]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/11-crown-street-colony-street-townhomes'>11 Crown Street - Colony Street Townhomes</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>12288 sq. ft.</td></tr></table>',
#     'times': ['2021-11-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-12'>Westbrook Village Phase 2 - Building 12</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>9946 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-11'>Westbrook Village Phase 2 - Building 11</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>10704 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-10'>Westbrook Village Phase 2 - Building 10</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>13748 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-09'>Westbrook Village Phase 2 - Building 09</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>6836 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-08'>Westbrook Village Phase 2 - Building 08</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>10378 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6908547, 41.764582]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/westbrook-village-phase-2-building-07'>Westbrook Village Phase 2 - Building 07</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>8647 sq. ft.</td></tr></table>',
#     'times': ['2021-11-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.4681875, 44.3692263]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/maple-corner-passive-house'>Maple Corner Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1288 sq. ft.</td></tr></table>',
#     'times': ['2021-11-01T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-73.9923596, 40.3042778]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/hom-hanan-house'>Hom Hanan House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1819 sq. ft.</td></tr></table>',
#     'times': ['2021-10-08T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-75.1635262, 39.9527237]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/anthony-wayne-iii'>Anthony Wayne III</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>39806 sq. ft.</td></tr></table>',
#     'times': ['2021-10-06T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-122.3300624, 47.6038321]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/1300-pike'>1300 Pike</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>29490 sq. ft.</td></tr></table>',
#     'times': ['2021-09-27T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-70.803452, 43.970581]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/fortin-residence'>Fortin Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1019 sq. ft.</td></tr></table>',
#     'times': ['2021-09-13T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-87.8265089, 42.128704]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/northbrook-park-district-activity-center'>Northbrook Park District Activity Center</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Government / Public</td></tr><tr><td><strong>Construction Type</strong></td><td>Insulated Concrete Form (ICF)</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>44048 sq. ft.</td></tr></table>',
#     'times': ['2021-08-20T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-110.9748477, 32.2228765]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/sonoran-desert-passive'>Sonoran Desert Passive</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2925 sq. ft.</td></tr></table>',
#     'times': ['2021-08-20T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-69.96497497313277, 43.77249795]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/bowdoin-college-scsc-llc'>Bowdoin College SCSC - LLC</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>School / Education</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5373 sq. ft.</td></tr></table>',
#     'times': ['2021-08-04T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-123.0950506, 44.0505054]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/rose-lane-passive-house'>Rose Lane Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1730 sq. ft.</td></tr></table>',
#     'times': ['2021-08-04T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-73.8785937, 40.8466508]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/mapes-apartments'>Mapes Apartments</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Masonry</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>29879 sq. ft.</td></tr></table>',
#     'times': ['2021-07-08T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-77.8616386, 40.7944504]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/stonebridge-senior-housing-phase-2'>Stonebridge Senior Housing Phase 2</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>55698 sq. ft.</td></tr></table>',
#     'times': ['2021-07-01T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-74.2154239, 41.9278705]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/olive-passive-house'>Olive Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1484 sq. ft.</td></tr></table>',
#     'times': ['2021-06-30T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-76.7870991, 41.20484]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/muncy-greene-w-community-space'>Muncy Greene (w/ Community Space)</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7008 sq. ft.</td></tr></table>',
#     'times': ['2021-06-24T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-70.88806837480472, 42.9280119]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/main-street-south-berwick-me-03908'>Main Street South Berwick ME 03908</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>20290 sq. ft.</td></tr></table>',
#     'times': ['2021-06-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-77.0365427, 38.8950368]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/harrison-street-infill'>Harrison Street Infill</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3650 sq. ft.</td></tr></table>',
#     'times': ['2021-06-16T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.4495005, 41.4501021]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/hawkins-yurgalevitch-passive-house'>Hawkins-Yurgalevitch Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>Retrofit</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3749 sq. ft.</td></tr></table>',
#     'times': ['2021-05-19T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.5219215, 42.9750374]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/sugarbush-house'>Sugarbush House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1427 sq. ft.</td></tr></table>',
#     'times': ['2021-04-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-122.478836, 48.7544012]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/bundle-mobile-office'>[bundle] mobile office</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Office</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>197 sq. ft.</td></tr></table>',
#     'times': ['2021-04-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.6892886696998, 45.30202559999999]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/saltbox-house'>Saltbox House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2472 sq. ft.</td></tr></table>',
#     'times': ['2021-03-17T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-124.4094086, 43.1195634]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/willrett-residence'>Willrett Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1847 sq. ft.</td></tr></table>',
#     'times': ['2021-03-17T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-93.2654692, 44.9772995]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/hook-ladder'>Hook & Ladder</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>53167 sq. ft.</td></tr></table>',
#     'times': ['2021-03-16T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-87.7887615, 41.8878145]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/carroll-center-additionrenovation'>Carroll Center Addition/Renovation</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>Addition</td></tr><tr><td><strong>Building Function</strong></td><td>School / Education</td></tr><tr><td><strong>Construction Type</strong></td><td>Masonry</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7667 sq. ft.</td></tr></table>',
#     'times': ['2021-03-10T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-77.503606, 42.7623645]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/indwell-mcquesten-lofts-hamilton-public-library-parkdale-branch'>Indwell McQuesten Lofts & Hamilton Public Library - Parkdale Branch</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>31657 sq. ft.</td></tr></table>',
#     'times': ['2021-02-17T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-74.0060152, 40.7127281]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/577-west-161st-street'>577 West 161st Street</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Mixed-Use</td></tr><tr><td><strong>Construction Type</strong></td><td>Masonry</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>16321 sq. ft.</td></tr></table>',
#     'times': ['2021-02-10T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-75.0562785, 41.7673105]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/seminary-hill-ciders'>Seminary Hill Ciders</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Other Non-Residential</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7542 sq. ft.</td></tr></table>',
#     'times': ['2021-02-05T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-120.4746427, 56.7165281]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/doig-river-cultural-center'>Doig River Cultural Center</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Government / Public</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5514 sq. ft.</td></tr></table>',
#     'times': ['2021-02-01T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-122.17532672432489, 47.2198644]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/foley-residence'>Foley Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1986 sq. ft.</td></tr></table>',
#     'times': ['2021-01-26T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.7259271, 42.859526]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/ames-hill-passive'>Ames Hill Passive</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1784 sq. ft.</td></tr></table>',
#     'times': ['2021-01-15T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.1056157, 42.3750997]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/finch-cambridge'>Finch Cambridge</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>101024 sq. ft.</td></tr></table>',
#     'times': ['2021-01-14T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-87.8342362, 42.2789117]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/vandercreek-residence'>VanDercreek Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2902 sq. ft.</td></tr></table>',
#     'times': ['2021-01-13T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-79.7647705, 40.5697893]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/pioneer-apartments'>Pioneer Apartments</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>42069 sq. ft.</td></tr></table>',
#     'times': ['2021-01-07T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-87.6244212, 41.8755616]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/yannell-passive-house'>Yannell Passive House</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>Retrofit</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3884 sq. ft.</td></tr></table>',
#     'times': ['2020-12-03T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-73.6731749, 42.4134168]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/columbia-county-habitat-passive-townhomes-3'>Columbia County Habitat Passive Townhomes 3</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2872 sq. ft.</td></tr></table>',
#     'times': ['2020-11-18T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-117.4235106, 47.6571934]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/bertucci-pfundt-residence'>Bertucci Pfundt Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2224 sq. ft.</td></tr></table>',
#     'times': ['2020-11-12T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-85.7058146, 41.6750375]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/spice-residence'>Spice Residence</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2104 sq. ft.</td></tr></table>',
#     'times': ['2020-10-14T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.0852695, 42.1294712]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/parade-street-commons-east-building'>Parade Street Commons East - Building A</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7603 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.0852695, 42.1294712]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/parade-street-commons-east-building-e'>Parade Street Commons East - Building E</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Other Non-Residential</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1035 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.0852695, 42.1294712]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/parade-street-commons-east-building-d'>Parade Street Commons East - Building D</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>9737 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.0852695, 42.1294712]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/parade-street-commons-east-building-c'>Parade Street Commons East - Building C</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>6120 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.0852695, 42.1294712]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/parade-street-commons-east-building-b'>Parade Street Commons East - Building B</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>24554 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-74.0060152, 40.7127281]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/542-w-153rd-st'>542 W 153rd St</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>28707 sq. ft.</td></tr></table>',
#     'times': ['2020-10-09T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-80.2440518, 36.0998131]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/3221-blenheim-place'>3221 Blenheim Place</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2138 sq. ft.</td></tr></table>',
#     'times': ['2020-09-30T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-74.0104179, 41.5034271]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/north-miller-passive-multifamily'>North Miller Passive Multifamily</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>Retrofit</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>2354 sq. ft.</td></tr></table>',
#     'times': ['2020-09-23T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-88.6078921, 42.2525476]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/wildwood-drive'>Wildwood Drive</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3551 sq. ft.</td></tr></table>',
#     'times': ['2020-09-15T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-76.7870991, 41.20484]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/muncy-greene-building-400'>Muncy Greene - Building 400</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5533 sq. ft.</td></tr></table>',
#     'times': ['2020-08-21T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-76.7870991, 41.20484]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/muncy-greene-building-1000'>Muncy Greene - Building 1000</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5533 sq. ft.</td></tr></table>',
#     'times': ['2020-08-21T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-76.7870991, 41.20484]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/muncy-greene-building-900'>Muncy Greene - Building 900</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5533 sq. ft.</td></tr></table>',
#     'times': ['2020-08-21T00:00:00']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-76.7870991, 41.20484]]},
#    'properties': {'marker-color': '#79BD9A',
#     'marker-symbol': 'building',
# ...
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>6225 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989773']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/mlk-tyler-street-building-5'>MLK / Tyler Street Building 5</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>6225 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989783']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/mlk-tyler-street-building-4'>MLK / Tyler Street Building 4</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>4800 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989792']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/mlk-tyler-street-building-3'>MLK / Tyler Street Building 3</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5550 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989802']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/mlk-tyler-street-building-2'>MLK / Tyler Street Building 2</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7470 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989813']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/mlk-tyler-street-building-1'>MLK / Tyler Street Building 1</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>7470 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989823']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-72.9250518, 41.3082138]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/340-dixwell-building-two'>340 Dixwell Building Two</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989831']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-79.9900861, 40.4416941]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/environmental-charter-school-high-school'>Environmental Charter School - High School</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989840']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.2092214, 42.3370414]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/residences-charles'>Residences on the Charles</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>45155 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989888']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-119.7026673, 34.4221319]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/montecito-casa-pasiva'>Montecito Casa Pasiva</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>4482 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989905']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-78.8783922, 42.8867166]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/west-side-homes-sustainable-rehabilitation-infill-housing-rhode-island'>West Side Homes Sustainable Rehabilitation & Infill Housing - Rhode Island</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>4614 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989917']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-70.082796, 41.7601093]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/brewster-woods-community-housing-building-40'>Brewster Woods Community Housing - Building 40</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>28296 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989929']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.1056157, 42.3750997]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/jp-federal-building-5'>JP Federal - Building 5</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Mixed-Use</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>73313 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989940']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.1056157, 42.3750997]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/jp-federal-building-1'>JP Federal - Building 1</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Mixed-Use</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>57899 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989953']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.0582912, 42.3602534]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-m'>Bunker Hill Housing - Phase 1 (Building M)</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>106660 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989964']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-71.0582912, 42.3602534]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/bunker-hill-housing-phase-1-building-f'>Bunker Hill Housing - Phase 1 (Building F)</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>234654 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989975']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-70.2548596, 43.6610277]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/337-cumberland'>337 Cumberland</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Mixed-Use</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>55270 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989987']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-70.9750426, 41.9903787]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/mcelwain-apartments'>McElwain Apartments</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>44189 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.989999']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-87.6244212, 41.8755616]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/conservatory-apartments'>Conservatory Apartments</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>22848 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.990011']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-93.6737694, 42.0359038]]},
#    'properties': {'marker-color': '#C4F09E',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/west-don-ravine-home'>West Don Ravine Home</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>3737 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.990022']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-94.7630041, 36.9875663]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-size': 'large',
#     'name': "<a href='https://www.phius.org/certified-project-database/811-gladstone'>811 Gladstone</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Multifamily</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>90828 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.990033']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-105.99959752584583, 39.225224499999996]]},
#    'properties': {'marker-color': '#FFFFFF',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/fairplay'>Fairplay</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Single-Family</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>1155 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.990044']}},
#   {'type': 'Feature',
#    'geometry': {'type': 'MultiPoint',
#     'coordinates': [[-121.5445822, 55.0947165]]},
#    'properties': {'marker-color': '#C4F09E',
#     'marker-symbol': 'building',
#     'name': "<a href='https://www.phius.org/certified-project-database/west-moberly-health-centre'>West Moberly Health Centre</a>",
#     'description': '<table><tr><td>Certified by</td><td><a href="https://www.phius.org">PHIUS</a></td></tr><tr><td><strong>Project Type</strong></td><td>New Construction</td></tr><tr><td><strong>Building Function</strong></td><td>Other Non-Residential</td></tr><tr><td><strong>Construction Type</strong></td><td>Wood Frame</td></tr><tr><td><strong>INT. Conditioned Floor Area</strong></td><td>5400 sq. ft.</td></tr></table>',
#     'times': ['2023-04-07T07:48:52.990057']}}]}

# %%
layer

# %%
m = folium.Map(location=(40, -75), control_scale=True, zoom_start=4)
layer = folium.plugins.TimestampedGeoJson(out, transition_time=200, loop=True, auto_play=True, 
                                 add_last_point=True, period='P1M', min_speed=0.1, max_speed=10, 
                                 loop_button=False, date_options='YYYY-MM-DD HH:mm:ss', 
                                 time_slider_drag_update=False, duration=None)
m.add_child(layer)
fullscreen = folium.plugins.Fullscreen()
m.add_child(fullscreen)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4b93eb0bb18145eb99b9edaf342a443a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jquery/2.0.0/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/iso8601-js-period%400.2.1/iso8601.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-timedimension%401.1.1/dist/leaflet.timedimension.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22s ...

# %%
def folium_map(df, color={0: '#55AAFF', 1: '#00F'},
               tformat='%a %d.%-m.%Y %-H:%M', timestamped=True):
    import folium
    import folium.plugins

    m = folium.Map(location=(df['LAT'].mean(), df['LON'].mean()),
                   control_scale=True, zoom_start=14)
    df = df.drop_duplicates(subset=['LAT', 'LON'])
    for name, grouped in df.groupby(df['Segel'].diff().abs().cumsum()):
        coords = list(zip(grouped['LAT'], grouped['LON']))
        folium.PolyLine(coords, popup=None,
                        tooltip=grouped.index[0].strftime(tformat) + ' to ' + \
                                grouped.index[-1].strftime(tformat),
                        color=color[grouped['Segel'].median()]).add_to(m)
    if timestamped:
        geoj = geojson(df)
        timelayer = folium.plugins.TimestampedGeoJson(geoj,
                                                      period='PT30S',
                                                      duration='PT1M')
        m.add_child(timelayer)

    return m


fullscreen = folium.plugins.Fullscreen()
m.add_child(fullscreen)
